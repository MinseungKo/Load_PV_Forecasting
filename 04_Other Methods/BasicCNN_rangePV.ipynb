# %%
import tensorflow as tf
import pandas as pd

tf.compat.v1.disable_v2_behavior()

import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout
from scipy import signal
import openpyxl
import seaborn as sns
from keijzer import *
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply
from tensorflow.keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from tensorflow.keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
from tensorflow.keras.utils import plot_model
from tensorflow.keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math
# Out:
# WARNING:tensorflow:From C:\Users\Smartgrid_ML\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
PV = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/seobu_pv.csv'
pv_source = pd.read_csv(PV, encoding='CP949')
pv_source = pd.DataFrame(pv_source)
pv_source = pv_source.iloc[0:1277, :]
pv_data = np.array(pv_source)

weather_17 = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/mokpo_2017.csv'
weather_18 = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/mokpo_2018.csv'
weather_19 = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/mokpo_2019.csv'
weather_20 = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/mokpo_2020.csv'

weather_17 = pd.read_csv(weather_17, encoding='CP949')
weather_18 = pd.read_csv(weather_18, encoding='CP949')
weather_19 = pd.read_csv(weather_19, encoding='CP949')
weather_20 = pd.read_csv(weather_20, encoding='CP949')
weather = pd.concat([weather_17,weather_18,weather_19,weather_20])
weather_data = np.array(weather)

pv_data = np.nan_to_num(pv_data)
weather_data = np.nan_to_num(weather_data)
pv_dat = pv_data[:, 2:]
weather_dat = weather_data[:, 3:]
pv_dat = pv_dat.reshape(-1,1)

dataset = np.hstack([pv_dat, weather_dat])
index = ['Measured PV', 'Temperature C', 'Rainfall', 'Wind speed', 'Wind direction', 'Humidity', 'Air pressure', 'Dew point C', 'Sunshine', 'Solar radiation', 'Snowfall', 'Cloud cover', 'Surface temp C']

df = pd.DataFrame(dataset, columns=index)
df.head()
df = df.fillna(0)
min_max_scaler = preprocessing.MinMaxScaler()
norm_df = pd.DataFrame(min_max_scaler.fit_transform(df), 
                             columns=df.columns, 
                             index=df.index)
norm_df.head()
# Out:
#    Measured PV  Temperature C  Rainfall  Wind speed  Wind direction  Humidity  \
# 0          0.0       0.354298       0.0    0.023256        0.000000      0.89
# 1          0.0       0.339623       0.0    0.104651        0.444444      0.93
# 2          0.0       0.320755       0.0    0.046512        0.388889      0.93
# 3          0.0       0.303983       0.0    0.087209        0.444444      0.94
# 4          0.0       0.287212       0.0    0.104651        0.444444      0.95
#
#    Air pressure  Dew point C  Sunshine  Solar radiation  Snowfall  \
# 0      0.189696     0.444681       0.0              0.0       0.0
# 1      0.189696     0.442553       0.0              0.0       0.0
# 2      0.177986     0.423404       0.0              0.0       0.0
# 3      0.170960     0.410638       0.0              0.0       0.0
# 4      0.161593     0.395745       0.0              0.0       0.0
#
#    Cloud cover  Surface temp C
# 0          0.6        0.141834
# 1          0.0        0.117479
# 2          0.0        0.103152
# 3          0.0        0.095989
# 4          0.0        0.088825

# %%
norm_df = np.array(norm_df)
print(norm_df[:,0])
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
def get_flops(model):
    run_meta = tf.RunMetadata()
    opts = tf.profiler.ProfileOptionBuilder.float_operation()

    # We use the Keras session graph in the call to the profiler.
    flops = tf.profiler.profile(graph=K.get_session().graph,
                                run_meta=run_meta, cmd='op', options=opts)

    return flops.total_float_ops  # Prints the "flops" of the model.

def create_dataset(dataset, timesteps, output_timesteps):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps):(i+timesteps+output_timesteps), :])
    return np.array(dataX), np.array(dataY)

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
timesteps = 30
output_timesteps = 12

X, Y = create_dataset(norm_df, timesteps, output_timesteps)

trX = X[:18389, :, :]
vaX = X[18389:21447, :, :]
teX = X[21447:, :, :]
trY = Y[:18389, :, 0]
vaY = Y[18389:21447, :, 0]
teY = Y[21447:, :, 0]

print(trX.shape)
print(trY.shape)
print(teX.shape)
# Out:
# (18389, 30, 13)
# (18389, 12)
# (9158, 30, 13)

# %%
with tf.device('/gpu:0'):
    num_features = 13
    hfilters = 256
    hkernel_size1 = 2
    hkernel_size2 = 4
    visible1 = Input(shape=(timesteps, num_features))
    d1 = Conv1D(filters=256, kernel_size=hkernel_size1, padding='causal', activation='relu')(visible1)
    d1 = Activation(activations.relu)(d1)
    d1 = Conv1D(filters=256, kernel_size=hkernel_size2, padding='causal', activation='relu')(d1)
    d1 = Activation(activations.relu)(d1)
    d1 = MaxPooling1D(pool_size=2, strides=1, padding='same')(d1)

    d1 = Conv1D(filters=128, kernel_size=hkernel_size1, padding='causal', activation='relu')(d1)
    d1 = Activation(activations.relu)(d1)
    d1 = Conv1D(filters=128, kernel_size=hkernel_size2, padding='causal', activation='relu')(d1)
    d1 = Activation(activations.relu)(d1)
    d1 = MaxPooling1D(pool_size=2, strides=1, padding='same')(d1)
    
    d1 = Conv1D(filters=64, kernel_size=hkernel_size1, padding='causal', activation='relu')(d1)
    d1 = Activation(activations.relu)(d1)
    d1 = Conv1D(filters=64, kernel_size=hkernel_size2, padding='causal', activation='relu')(d1)
    d1 = Activation(activations.relu)(d1)
    d1 = MaxPooling1D(pool_size=2, strides=1, padding='same')(d1)
    
    d1 = Conv1D(filters=32, kernel_size=hkernel_size1, padding='causal', activation='relu')(d1)
    d1 = Activation(activations.relu)(d1)
    d1 = Conv1D(filters=32, kernel_size=hkernel_size2, padding='causal', activation='relu')(d1)
    d1 = Activation(activations.relu)(d1)
    d1 = MaxPooling1D(pool_size=2, strides=1, padding='same')(d1)
    
    d1 = Conv1D(filters=16, kernel_size=hkernel_size1, padding='causal', activation='relu')(d1)
    d1 = Activation(activations.relu)(d1)
    d1 = Conv1D(filters=16, kernel_size=hkernel_size2, padding='causal', activation='relu')(d1)
    d1 = Activation(activations.relu)(d1)
    d1 = MaxPooling1D(pool_size=2, strides=1, padding='same')(d1)

    out = Conv1D(512, 1, padding='same', activation='relu')(d1)   # 256, 11X10=110  
    out = Dropout(0.2)(out)   
    
    out = Conv1D(256, 1, padding='same', activation='relu')(out) # 512,  110X5=550
    out = Dropout(0.2)(out)  
    
    out = GlobalMaxPooling1D()(out) # pool_size=2, strides=1
    
    out = Dense(output_timesteps)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
    
    model.compile(loss=root_mean_squared_error, optimizer='adam', metrics=[root_mean_squared_error, 'mse', 'mae'])
    early_stopping =EarlyStopping(monitor='val_loss', patience=100)
    batch_size = 100
    epochs = 1000

    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 30, 13)]          0
# _________________________________________________________________
# conv1d_66 (Conv1D)           (None, 30, 256)           6912
# _________________________________________________________________
# activation_58 (Activation)   (None, 30, 256)           0
# _________________________________________________________________
# conv1d_67 (Conv1D)           (None, 30, 256)           262400
# _________________________________________________________________
# activation_59 (Activation)   (None, 30, 256)           0
# _________________________________________________________________
# max_pooling1d_31 (MaxPooling (None, 30, 256)           0
# _________________________________________________________________
# conv1d_68 (Conv1D)           (None, 30, 128)           65664
# _________________________________________________________________
# activation_60 (Activation)   (None, 30, 128)           0
# _________________________________________________________________
# conv1d_69 (Conv1D)           (None, 30, 128)           65664
# _________________________________________________________________
# activation_61 (Activation)   (None, 30, 128)           0
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 30, 128)           0
# _________________________________________________________________
# conv1d_70 (Conv1D)           (None, 30, 64)            16448
# _________________________________________________________________
# activation_62 (Activation)   (None, 30, 64)            0
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 30, 64)            16448
# _________________________________________________________________
# activation_63 (Activation)   (None, 30, 64)            0
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 30, 64)            0
# _________________________________________________________________
# conv1d_72 (Conv1D)           (None, 30, 32)            4128
# _________________________________________________________________
# activation_64 (Activation)   (None, 30, 32)            0
# _________________________________________________________________
# conv1d_73 (Conv1D)           (None, 30, 32)            4128
# _________________________________________________________________
# activation_65 (Activation)   (None, 30, 32)            0
# _________________________________________________________________
# max_pooling1d_34 (MaxPooling (None, 30, 32)            0
# _________________________________________________________________
# conv1d_74 (Conv1D)           (None, 30, 16)            1040
# _________________________________________________________________
# activation_66 (Activation)   (None, 30, 16)            0
# _________________________________________________________________
# conv1d_75 (Conv1D)           (None, 30, 16)            1040
# _________________________________________________________________
# activation_67 (Activation)   (None, 30, 16)            0
# _________________________________________________________________
# max_pooling1d_35 (MaxPooling (None, 30, 16)            0
# _________________________________________________________________
# conv1d_76 (Conv1D)           (None, 30, 512)           8704
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30, 512)           0
# _________________________________________________________________
# conv1d_77 (Conv1D)           (None, 30, 256)           131328
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 30, 256)           0
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 12)                3084
# =================================================================
# Total params: 586,988
# Trainable params: 586,988
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
    # %%time
    hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Train on 18389 samples, validate on 3058 samples
# Epoch 1/1000
# 18300/18389 [============================>.] - ETA: 0s - loss: 0.1952 - root_mean_squared_error: 0.1952 - mean_squared_error: 0.0418 - mean_absolute_error: 0.1488
# C:\Users\Smartgrid_ML\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 18389/18389 [==============================] - 4s 194us/sample - loss: 0.1953 - root_mean_squared_error: 0.1953 - mean_squared_error: 0.0418 - mean_absolute_error: 0.1487 - val_loss: 0.2118 - val_root_mean_squared_error: 0.2118 - val_mean_squared_error: 0.0449 - val_mean_absolute_error: 0.1465
# Epoch 2/1000
# 18389/18389 [==============================] - 3s 178us/sample - loss: 0.1446 - root_mean_squared_error: 0.1446 - mean_squared_error: 0.0218 - mean_absolute_error: 0.1037 - val_loss: 0.2052 - val_root_mean_squared_error: 0.2049 - val_mean_squared_error: 0.0422 - val_mean_absolute_error: 0.1360
# Epoch 3/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.1363 - root_mean_squared_error: 0.1364 - mean_squared_error: 0.0194 - mean_absolute_error: 0.0953 - val_loss: 0.2271 - val_root_mean_squared_error: 0.2273 - val_mean_squared_error: 0.0518 - val_mean_absolute_error: 0.1451
# Epoch 4/1000
# 18389/18389 [==============================] - 3s 178us/sample - loss: 0.1340 - root_mean_squared_error: 0.1340 - mean_squared_error: 0.0188 - mean_absolute_error: 0.0926 - val_loss: 0.2094 - val_root_mean_squared_error: 0.2093 - val_mean_squared_error: 0.0440 - val_mean_absolute_error: 0.1379
# Epoch 5/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.1318 - root_mean_squared_error: 0.1318 - mean_squared_error: 0.0182 - mean_absolute_error: 0.0917 - val_loss: 0.2090 - val_root_mean_squared_error: 0.2087 - val_mean_squared_error: 0.0438 - val_mean_absolute_error: 0.1360
# Epoch 6/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.1297 - root_mean_squared_error: 0.1297 - mean_squared_error: 0.0176 - mean_absolute_error: 0.0888 - val_loss: 0.1998 - val_root_mean_squared_error: 0.2001 - val_mean_squared_error: 0.0401 - val_mean_absolute_error: 0.1294
# Epoch 7/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.1274 - root_mean_squared_error: 0.1274 - mean_squared_error: 0.0170 - mean_absolute_error: 0.0868 - val_loss: 0.1941 - val_root_mean_squared_error: 0.1938 - val_mean_squared_error: 0.0378 - val_mean_absolute_error: 0.1278
# Epoch 8/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.1258 - root_mean_squared_error: 0.1258 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0845 - val_loss: 0.2077 - val_root_mean_squared_error: 0.2076 - val_mean_squared_error: 0.0433 - val_mean_absolute_error: 0.1314
# Epoch 9/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.1255 - root_mean_squared_error: 0.1255 - mean_squared_error: 0.0166 - mean_absolute_error: 0.0845 - val_loss: 0.2094 - val_root_mean_squared_error: 0.2097 - val_mean_squared_error: 0.0440 - val_mean_absolute_error: 0.1343
# Epoch 10/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.1222 - root_mean_squared_error: 0.1222 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0818 - val_loss: 0.1979 - val_root_mean_squared_error: 0.1979 - val_mean_squared_error: 0.0393 - val_mean_absolute_error: 0.1270
# Epoch 11/1000
# 18389/18389 [==============================] - 3s 168us/sample - loss: 0.1225 - root_mean_squared_error: 0.1225 - mean_squared_error: 0.0158 - mean_absolute_error: 0.0819 - val_loss: 0.2024 - val_root_mean_squared_error: 0.2026 - val_mean_squared_error: 0.0411 - val_mean_absolute_error: 0.1318
# Epoch 12/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.1187 - root_mean_squared_error: 0.1187 - mean_squared_error: 0.0148 - mean_absolute_error: 0.0792 - val_loss: 0.1958 - val_root_mean_squared_error: 0.1955 - val_mean_squared_error: 0.0384 - val_mean_absolute_error: 0.1265
# Epoch 13/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.1172 - root_mean_squared_error: 0.1173 - mean_squared_error: 0.0145 - mean_absolute_error: 0.0777 - val_loss: 0.2002 - val_root_mean_squared_error: 0.2000 - val_mean_squared_error: 0.0402 - val_mean_absolute_error: 0.1255
# Epoch 14/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.1151 - root_mean_squared_error: 0.1151 - mean_squared_error: 0.0139 - mean_absolute_error: 0.0762 - val_loss: 0.1883 - val_root_mean_squared_error: 0.1881 - val_mean_squared_error: 0.0356 - val_mean_absolute_error: 0.1207
# Epoch 15/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.1138 - root_mean_squared_error: 0.1138 - mean_squared_error: 0.0136 - mean_absolute_error: 0.0751 - val_loss: 0.1824 - val_root_mean_squared_error: 0.1823 - val_mean_squared_error: 0.0333 - val_mean_absolute_error: 0.1161
# Epoch 16/1000
# 18389/18389 [==============================] - 3s 169us/sample - loss: 0.1129 - root_mean_squared_error: 0.1130 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0745 - val_loss: 0.1794 - val_root_mean_squared_error: 0.1794 - val_mean_squared_error: 0.0323 - val_mean_absolute_error: 0.1153
# Epoch 17/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.1102 - root_mean_squared_error: 0.1103 - mean_squared_error: 0.0129 - mean_absolute_error: 0.0724 - val_loss: 0.1744 - val_root_mean_squared_error: 0.1745 - val_mean_squared_error: 0.0305 - val_mean_absolute_error: 0.1114
# Epoch 18/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.1107 - root_mean_squared_error: 0.1107 - mean_squared_error: 0.0129 - mean_absolute_error: 0.0729 - val_loss: 0.1870 - val_root_mean_squared_error: 0.1872 - val_mean_squared_error: 0.0351 - val_mean_absolute_error: 0.1161
# Epoch 19/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.1092 - root_mean_squared_error: 0.1093 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0717 - val_loss: 0.1932 - val_root_mean_squared_error: 0.1933 - val_mean_squared_error: 0.0374 - val_mean_absolute_error: 0.1241
# Epoch 20/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.1083 - root_mean_squared_error: 0.1083 - mean_squared_error: 0.0124 - mean_absolute_error: 0.0712 - val_loss: 0.1782 - val_root_mean_squared_error: 0.1780 - val_mean_squared_error: 0.0319 - val_mean_absolute_error: 0.1118
# Epoch 21/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.1075 - root_mean_squared_error: 0.1076 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0705 - val_loss: 0.1827 - val_root_mean_squared_error: 0.1831 - val_mean_squared_error: 0.0335 - val_mean_absolute_error: 0.1131
# Epoch 22/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.1136 - root_mean_squared_error: 0.1136 - mean_squared_error: 0.0136 - mean_absolute_error: 0.0748 - val_loss: 0.1825 - val_root_mean_squared_error: 0.1825 - val_mean_squared_error: 0.0334 - val_mean_absolute_error: 0.1173
# Epoch 23/1000
# 18389/18389 [==============================] - 3s 169us/sample - loss: 0.1085 - root_mean_squared_error: 0.1086 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0712 - val_loss: 0.1797 - val_root_mean_squared_error: 0.1797 - val_mean_squared_error: 0.0324 - val_mean_absolute_error: 0.1181
# Epoch 24/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.1032 - root_mean_squared_error: 0.1032 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0675 - val_loss: 0.1807 - val_root_mean_squared_error: 0.1808 - val_mean_squared_error: 0.0328 - val_mean_absolute_error: 0.1138
# Epoch 25/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.1040 - root_mean_squared_error: 0.1041 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0682 - val_loss: 0.1909 - val_root_mean_squared_error: 0.1907 - val_mean_squared_error: 0.0365 - val_mean_absolute_error: 0.1207
# Epoch 26/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.1029 - root_mean_squared_error: 0.1030 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0675 - val_loss: 0.1948 - val_root_mean_squared_error: 0.1946 - val_mean_squared_error: 0.0381 - val_mean_absolute_error: 0.1223
# Epoch 27/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.1029 - root_mean_squared_error: 0.1029 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0676 - val_loss: 0.1875 - val_root_mean_squared_error: 0.1875 - val_mean_squared_error: 0.0353 - val_mean_absolute_error: 0.1189
# Epoch 28/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.1028 - root_mean_squared_error: 0.1028 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0678 - val_loss: 0.1865 - val_root_mean_squared_error: 0.1870 - val_mean_squared_error: 0.0350 - val_mean_absolute_error: 0.1163
# Epoch 29/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.0990 - root_mean_squared_error: 0.0991 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0652 - val_loss: 0.1915 - val_root_mean_squared_error: 0.1914 - val_mean_squared_error: 0.0368 - val_mean_absolute_error: 0.1167
# Epoch 30/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.1018 - root_mean_squared_error: 0.1018 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0670 - val_loss: 0.1805 - val_root_mean_squared_error: 0.1803 - val_mean_squared_error: 0.0326 - val_mean_absolute_error: 0.1143
# Epoch 31/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.1005 - root_mean_squared_error: 0.1006 - mean_squared_error: 0.0108 - mean_absolute_error: 0.0662 - val_loss: 0.1938 - val_root_mean_squared_error: 0.1941 - val_mean_squared_error: 0.0377 - val_mean_absolute_error: 0.1180
# Epoch 32/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0978 - root_mean_squared_error: 0.0979 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0641 - val_loss: 0.1995 - val_root_mean_squared_error: 0.1992 - val_mean_squared_error: 0.0400 - val_mean_absolute_error: 0.1223
# Epoch 33/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0943 - root_mean_squared_error: 0.0944 - mean_squared_error: 0.0095 - mean_absolute_error: 0.0614 - val_loss: 0.1878 - val_root_mean_squared_error: 0.1879 - val_mean_squared_error: 0.0354 - val_mean_absolute_error: 0.1177
# Epoch 34/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0953 - root_mean_squared_error: 0.0954 - mean_squared_error: 0.0097 - mean_absolute_error: 0.0623 - val_loss: 0.1886 - val_root_mean_squared_error: 0.1883 - val_mean_squared_error: 0.0357 - val_mean_absolute_error: 0.1235
# Epoch 35/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0936 - root_mean_squared_error: 0.0936 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0617 - val_loss: 0.1892 - val_root_mean_squared_error: 0.1892 - val_mean_squared_error: 0.0359 - val_mean_absolute_error: 0.1209
# Epoch 36/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0941 - root_mean_squared_error: 0.0941 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0619 - val_loss: 0.1914 - val_root_mean_squared_error: 0.1916 - val_mean_squared_error: 0.0368 - val_mean_absolute_error: 0.1228
# Epoch 37/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0925 - root_mean_squared_error: 0.0926 - mean_squared_error: 0.0092 - mean_absolute_error: 0.0606 - val_loss: 0.1843 - val_root_mean_squared_error: 0.1844 - val_mean_squared_error: 0.0341 - val_mean_absolute_error: 0.1163
# Epoch 38/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0925 - root_mean_squared_error: 0.0925 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0605 - val_loss: 0.1897 - val_root_mean_squared_error: 0.1895 - val_mean_squared_error: 0.0362 - val_mean_absolute_error: 0.1218
# Epoch 39/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0915 - root_mean_squared_error: 0.0915 - mean_squared_error: 0.0090 - mean_absolute_error: 0.0597 - val_loss: 0.1843 - val_root_mean_squared_error: 0.1840 - val_mean_squared_error: 0.0341 - val_mean_absolute_error: 0.1159
# Epoch 40/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0898 - root_mean_squared_error: 0.0899 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0585 - val_loss: 0.1893 - val_root_mean_squared_error: 0.1896 - val_mean_squared_error: 0.0360 - val_mean_absolute_error: 0.1200
# Epoch 41/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0871 - root_mean_squared_error: 0.0871 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0568 - val_loss: 0.1900 - val_root_mean_squared_error: 0.1902 - val_mean_squared_error: 0.0363 - val_mean_absolute_error: 0.1182
# Epoch 42/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0885 - root_mean_squared_error: 0.0885 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0587 - val_loss: 0.1937 - val_root_mean_squared_error: 0.1936 - val_mean_squared_error: 0.0376 - val_mean_absolute_error: 0.1211
# Epoch 43/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0902 - root_mean_squared_error: 0.0902 - mean_squared_error: 0.0087 - mean_absolute_error: 0.0586 - val_loss: 0.1964 - val_root_mean_squared_error: 0.1967 - val_mean_squared_error: 0.0387 - val_mean_absolute_error: 0.1251
# Epoch 44/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0855 - root_mean_squared_error: 0.0856 - mean_squared_error: 0.0078 - mean_absolute_error: 0.0562 - val_loss: 0.1943 - val_root_mean_squared_error: 0.1943 - val_mean_squared_error: 0.0378 - val_mean_absolute_error: 0.1198
# Epoch 45/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0845 - root_mean_squared_error: 0.0846 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0556 - val_loss: 0.1936 - val_root_mean_squared_error: 0.1934 - val_mean_squared_error: 0.0376 - val_mean_absolute_error: 0.1197
# Epoch 46/1000
# 18389/18389 [==============================] - 3s 179us/sample - loss: 0.0865 - root_mean_squared_error: 0.0866 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0561 - val_loss: 0.2006 - val_root_mean_squared_error: 0.2005 - val_mean_squared_error: 0.0404 - val_mean_absolute_error: 0.1254
# Epoch 47/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0825 - root_mean_squared_error: 0.0826 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0543 - val_loss: 0.1933 - val_root_mean_squared_error: 0.1931 - val_mean_squared_error: 0.0374 - val_mean_absolute_error: 0.1210
# Epoch 48/1000
# 18389/18389 [==============================] - 3s 179us/sample - loss: 0.0825 - root_mean_squared_error: 0.0826 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0543 - val_loss: 0.1972 - val_root_mean_squared_error: 0.1971 - val_mean_squared_error: 0.0390 - val_mean_absolute_error: 0.1242
# Epoch 49/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0826 - root_mean_squared_error: 0.0826 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0542 - val_loss: 0.1922 - val_root_mean_squared_error: 0.1925 - val_mean_squared_error: 0.0371 - val_mean_absolute_error: 0.1214
# Epoch 50/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0799 - root_mean_squared_error: 0.0799 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0524 - val_loss: 0.2039 - val_root_mean_squared_error: 0.2041 - val_mean_squared_error: 0.0417 - val_mean_absolute_error: 0.1284
# Epoch 51/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0814 - root_mean_squared_error: 0.0815 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0533 - val_loss: 0.2064 - val_root_mean_squared_error: 0.2065 - val_mean_squared_error: 0.0428 - val_mean_absolute_error: 0.1282
# Epoch 52/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0798 - root_mean_squared_error: 0.0798 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0526 - val_loss: 0.2100 - val_root_mean_squared_error: 0.2100 - val_mean_squared_error: 0.0443 - val_mean_absolute_error: 0.1312
# Epoch 53/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0774 - root_mean_squared_error: 0.0775 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0508 - val_loss: 0.2104 - val_root_mean_squared_error: 0.2103 - val_mean_squared_error: 0.0444 - val_mean_absolute_error: 0.1296
# Epoch 54/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0775 - root_mean_squared_error: 0.0776 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0507 - val_loss: 0.2161 - val_root_mean_squared_error: 0.2164 - val_mean_squared_error: 0.0469 - val_mean_absolute_error: 0.1306
# Epoch 55/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0755 - root_mean_squared_error: 0.0756 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0492 - val_loss: 0.2095 - val_root_mean_squared_error: 0.2098 - val_mean_squared_error: 0.0441 - val_mean_absolute_error: 0.1274
# Epoch 56/1000
# 18389/18389 [==============================] - 3s 177us/sample - loss: 0.0752 - root_mean_squared_error: 0.0752 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0492 - val_loss: 0.2027 - val_root_mean_squared_error: 0.2030 - val_mean_squared_error: 0.0413 - val_mean_absolute_error: 0.1237
# Epoch 57/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0767 - root_mean_squared_error: 0.0767 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0499 - val_loss: 0.1935 - val_root_mean_squared_error: 0.1930 - val_mean_squared_error: 0.0376 - val_mean_absolute_error: 0.1203
# Epoch 58/1000
# 18389/18389 [==============================] - 3s 178us/sample - loss: 0.0750 - root_mean_squared_error: 0.0750 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0486 - val_loss: 0.1958 - val_root_mean_squared_error: 0.1957 - val_mean_squared_error: 0.0384 - val_mean_absolute_error: 0.1230
# Epoch 59/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0765 - root_mean_squared_error: 0.0765 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0503 - val_loss: 0.2002 - val_root_mean_squared_error: 0.2004 - val_mean_squared_error: 0.0402 - val_mean_absolute_error: 0.1207
# Epoch 60/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0742 - root_mean_squared_error: 0.0742 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0489 - val_loss: 0.1953 - val_root_mean_squared_error: 0.1953 - val_mean_squared_error: 0.0383 - val_mean_absolute_error: 0.1221
# Epoch 61/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0728 - root_mean_squared_error: 0.0728 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0477 - val_loss: 0.1991 - val_root_mean_squared_error: 0.1990 - val_mean_squared_error: 0.0398 - val_mean_absolute_error: 0.1240
# Epoch 62/1000
# 18389/18389 [==============================] - 3s 178us/sample - loss: 0.0731 - root_mean_squared_error: 0.0731 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0482 - val_loss: 0.1969 - val_root_mean_squared_error: 0.1972 - val_mean_squared_error: 0.0389 - val_mean_absolute_error: 0.1236
# Epoch 63/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0732 - root_mean_squared_error: 0.0732 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0483 - val_loss: 0.2033 - val_root_mean_squared_error: 0.2035 - val_mean_squared_error: 0.0415 - val_mean_absolute_error: 0.1268
# Epoch 64/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0729 - root_mean_squared_error: 0.0729 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0482 - val_loss: 0.2031 - val_root_mean_squared_error: 0.2029 - val_mean_squared_error: 0.0414 - val_mean_absolute_error: 0.1260
# Epoch 65/1000
# 18389/18389 [==============================] - 3s 169us/sample - loss: 0.0726 - root_mean_squared_error: 0.0727 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0484 - val_loss: 0.2053 - val_root_mean_squared_error: 0.2056 - val_mean_squared_error: 0.0423 - val_mean_absolute_error: 0.1239
# Epoch 66/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0713 - root_mean_squared_error: 0.0714 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0473 - val_loss: 0.1923 - val_root_mean_squared_error: 0.1924 - val_mean_squared_error: 0.0371 - val_mean_absolute_error: 0.1165
# Epoch 67/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0747 - root_mean_squared_error: 0.0747 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0490 - val_loss: 0.1948 - val_root_mean_squared_error: 0.1948 - val_mean_squared_error: 0.0381 - val_mean_absolute_error: 0.1203
# Epoch 68/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0710 - root_mean_squared_error: 0.0710 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0468 - val_loss: 0.1884 - val_root_mean_squared_error: 0.1887 - val_mean_squared_error: 0.0357 - val_mean_absolute_error: 0.1156
# Epoch 69/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0723 - root_mean_squared_error: 0.0723 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0476 - val_loss: 0.1760 - val_root_mean_squared_error: 0.1760 - val_mean_squared_error: 0.0311 - val_mean_absolute_error: 0.1097
# Epoch 70/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0710 - root_mean_squared_error: 0.0710 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0463 - val_loss: 0.1761 - val_root_mean_squared_error: 0.1760 - val_mean_squared_error: 0.0311 - val_mean_absolute_error: 0.1087
# Epoch 71/1000
# 18389/18389 [==============================] - 3s 179us/sample - loss: 0.0691 - root_mean_squared_error: 0.0691 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0453 - val_loss: 0.1789 - val_root_mean_squared_error: 0.1790 - val_mean_squared_error: 0.0322 - val_mean_absolute_error: 0.1085
# Epoch 72/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0673 - root_mean_squared_error: 0.0673 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0445 - val_loss: 0.1712 - val_root_mean_squared_error: 0.1714 - val_mean_squared_error: 0.0294 - val_mean_absolute_error: 0.1067
# Epoch 73/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0663 - root_mean_squared_error: 0.0663 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0434 - val_loss: 0.1738 - val_root_mean_squared_error: 0.1739 - val_mean_squared_error: 0.0304 - val_mean_absolute_error: 0.1104
# Epoch 74/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0660 - root_mean_squared_error: 0.0660 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0430 - val_loss: 0.1604 - val_root_mean_squared_error: 0.1604 - val_mean_squared_error: 0.0258 - val_mean_absolute_error: 0.1053
# Epoch 75/1000
# 18389/18389 [==============================] - 3s 178us/sample - loss: 0.0653 - root_mean_squared_error: 0.0653 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0432 - val_loss: 0.1655 - val_root_mean_squared_error: 0.1657 - val_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.1037
# Epoch 76/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0661 - root_mean_squared_error: 0.0661 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0435 - val_loss: 0.1619 - val_root_mean_squared_error: 0.1619 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.1023
# Epoch 77/1000
# 18389/18389 [==============================] - 3s 177us/sample - loss: 0.0654 - root_mean_squared_error: 0.0654 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0425 - val_loss: 0.1648 - val_root_mean_squared_error: 0.1645 - val_mean_squared_error: 0.0273 - val_mean_absolute_error: 0.1001
# Epoch 78/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0649 - root_mean_squared_error: 0.0649 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0426 - val_loss: 0.1446 - val_root_mean_squared_error: 0.1448 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0917
# Epoch 79/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0655 - root_mean_squared_error: 0.0655 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0427 - val_loss: 0.1456 - val_root_mean_squared_error: 0.1454 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0934
# Epoch 80/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0632 - root_mean_squared_error: 0.0632 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0410 - val_loss: 0.1520 - val_root_mean_squared_error: 0.1516 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.0946
# Epoch 81/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.0636 - root_mean_squared_error: 0.0636 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0415 - val_loss: 0.1452 - val_root_mean_squared_error: 0.1453 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0903
# Epoch 82/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0649 - root_mean_squared_error: 0.0649 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0428 - val_loss: 0.1469 - val_root_mean_squared_error: 0.1471 - val_mean_squared_error: 0.0217 - val_mean_absolute_error: 0.0982
# Epoch 83/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0685 - root_mean_squared_error: 0.0685 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0449 - val_loss: 0.1438 - val_root_mean_squared_error: 0.1440 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0953
# Epoch 84/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0670 - root_mean_squared_error: 0.0670 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0441 - val_loss: 0.1389 - val_root_mean_squared_error: 0.1390 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.0871
# Epoch 85/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0636 - root_mean_squared_error: 0.0636 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0412 - val_loss: 0.1482 - val_root_mean_squared_error: 0.1486 - val_mean_squared_error: 0.0221 - val_mean_absolute_error: 0.0940
# Epoch 86/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0645 - root_mean_squared_error: 0.0645 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0424 - val_loss: 0.1346 - val_root_mean_squared_error: 0.1346 - val_mean_squared_error: 0.0182 - val_mean_absolute_error: 0.0864
# Epoch 87/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0645 - root_mean_squared_error: 0.0645 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0417 - val_loss: 0.1392 - val_root_mean_squared_error: 0.1391 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.0878
# Epoch 88/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0622 - root_mean_squared_error: 0.0623 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0403 - val_loss: 0.1416 - val_root_mean_squared_error: 0.1416 - val_mean_squared_error: 0.0201 - val_mean_absolute_error: 0.0931
# Epoch 89/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0619 - root_mean_squared_error: 0.0619 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0403 - val_loss: 0.1413 - val_root_mean_squared_error: 0.1410 - val_mean_squared_error: 0.0201 - val_mean_absolute_error: 0.0951
# Epoch 90/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0612 - root_mean_squared_error: 0.0612 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0399 - val_loss: 0.1430 - val_root_mean_squared_error: 0.1430 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0902
# Epoch 91/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0589 - root_mean_squared_error: 0.0589 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0386 - val_loss: 0.1361 - val_root_mean_squared_error: 0.1360 - val_mean_squared_error: 0.0186 - val_mean_absolute_error: 0.0875
# Epoch 92/1000
# 18389/18389 [==============================] - 3s 177us/sample - loss: 0.0611 - root_mean_squared_error: 0.0611 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0399 - val_loss: 0.1374 - val_root_mean_squared_error: 0.1374 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.0898
# Epoch 93/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0630 - root_mean_squared_error: 0.0630 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0409 - val_loss: 0.1356 - val_root_mean_squared_error: 0.1354 - val_mean_squared_error: 0.0185 - val_mean_absolute_error: 0.0867
# Epoch 94/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0595 - root_mean_squared_error: 0.0595 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0386 - val_loss: 0.1408 - val_root_mean_squared_error: 0.1409 - val_mean_squared_error: 0.0199 - val_mean_absolute_error: 0.0960
# Epoch 95/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0589 - root_mean_squared_error: 0.0589 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0388 - val_loss: 0.1431 - val_root_mean_squared_error: 0.1430 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0954
# Epoch 96/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0589 - root_mean_squared_error: 0.0589 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0383 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1420 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0941
# Epoch 97/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0599 - root_mean_squared_error: 0.0599 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0391 - val_loss: 0.1379 - val_root_mean_squared_error: 0.1378 - val_mean_squared_error: 0.0191 - val_mean_absolute_error: 0.0918
# Epoch 98/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0611 - root_mean_squared_error: 0.0611 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0399 - val_loss: 0.1460 - val_root_mean_squared_error: 0.1458 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0923
# Epoch 99/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.0617 - root_mean_squared_error: 0.0617 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0405 - val_loss: 0.1409 - val_root_mean_squared_error: 0.1414 - val_mean_squared_error: 0.0199 - val_mean_absolute_error: 0.0928
# Epoch 100/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0595 - root_mean_squared_error: 0.0595 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0385 - val_loss: 0.1422 - val_root_mean_squared_error: 0.1422 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0951
# Epoch 101/1000
# 18389/18389 [==============================] - 3s 177us/sample - loss: 0.0591 - root_mean_squared_error: 0.0592 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0381 - val_loss: 0.1415 - val_root_mean_squared_error: 0.1417 - val_mean_squared_error: 0.0201 - val_mean_absolute_error: 0.0973
# Epoch 102/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0575 - root_mean_squared_error: 0.0575 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0377 - val_loss: 0.1387 - val_root_mean_squared_error: 0.1385 - val_mean_squared_error: 0.0193 - val_mean_absolute_error: 0.0918
# Epoch 103/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0565 - root_mean_squared_error: 0.0565 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0368 - val_loss: 0.1398 - val_root_mean_squared_error: 0.1397 - val_mean_squared_error: 0.0196 - val_mean_absolute_error: 0.0924
# Epoch 104/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0562 - root_mean_squared_error: 0.0562 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0368 - val_loss: 0.1371 - val_root_mean_squared_error: 0.1370 - val_mean_squared_error: 0.0189 - val_mean_absolute_error: 0.0926
# Epoch 105/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0552 - root_mean_squared_error: 0.0552 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0355 - val_loss: 0.1415 - val_root_mean_squared_error: 0.1414 - val_mean_squared_error: 0.0201 - val_mean_absolute_error: 0.0945
# Epoch 106/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0563 - root_mean_squared_error: 0.0563 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0367 - val_loss: 0.1391 - val_root_mean_squared_error: 0.1392 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.0960
# Epoch 107/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0546 - root_mean_squared_error: 0.0546 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0352 - val_loss: 0.1406 - val_root_mean_squared_error: 0.1407 - val_mean_squared_error: 0.0199 - val_mean_absolute_error: 0.0943
# Epoch 108/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0579 - root_mean_squared_error: 0.0580 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0372 - val_loss: 0.1432 - val_root_mean_squared_error: 0.1432 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0936
# Epoch 109/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0602 - root_mean_squared_error: 0.0602 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0385 - val_loss: 0.1390 - val_root_mean_squared_error: 0.1391 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.0995
# Epoch 110/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0581 - root_mean_squared_error: 0.0581 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0376 - val_loss: 0.1424 - val_root_mean_squared_error: 0.1422 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0975
# Epoch 111/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0549 - root_mean_squared_error: 0.0549 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0356 - val_loss: 0.1437 - val_root_mean_squared_error: 0.1437 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.0978
# Epoch 112/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0548 - root_mean_squared_error: 0.0548 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0353 - val_loss: 0.1419 - val_root_mean_squared_error: 0.1420 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0973
# Epoch 113/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0536 - root_mean_squared_error: 0.0536 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0349 - val_loss: 0.1466 - val_root_mean_squared_error: 0.1468 - val_mean_squared_error: 0.0216 - val_mean_absolute_error: 0.0998
# Epoch 114/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0527 - root_mean_squared_error: 0.0527 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0338 - val_loss: 0.1488 - val_root_mean_squared_error: 0.1488 - val_mean_squared_error: 0.0222 - val_mean_absolute_error: 0.1001
# Epoch 115/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0522 - root_mean_squared_error: 0.0522 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0335 - val_loss: 0.1439 - val_root_mean_squared_error: 0.1442 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0988
# Epoch 116/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0560 - root_mean_squared_error: 0.0560 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0361 - val_loss: 0.1452 - val_root_mean_squared_error: 0.1450 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.1009
# Epoch 117/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0546 - root_mean_squared_error: 0.0546 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0352 - val_loss: 0.1457 - val_root_mean_squared_error: 0.1456 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.0987
# Epoch 118/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0519 - root_mean_squared_error: 0.0519 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0334 - val_loss: 0.1510 - val_root_mean_squared_error: 0.1510 - val_mean_squared_error: 0.0229 - val_mean_absolute_error: 0.1032
# Epoch 119/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0505 - root_mean_squared_error: 0.0505 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0325 - val_loss: 0.1520 - val_root_mean_squared_error: 0.1518 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.1057
# Epoch 120/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0507 - root_mean_squared_error: 0.0507 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0326 - val_loss: 0.1455 - val_root_mean_squared_error: 0.1453 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.1014
# Epoch 121/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0500 - root_mean_squared_error: 0.0500 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0321 - val_loss: 0.1431 - val_root_mean_squared_error: 0.1432 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.1005
# Epoch 122/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0491 - root_mean_squared_error: 0.0491 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0314 - val_loss: 0.1424 - val_root_mean_squared_error: 0.1426 - val_mean_squared_error: 0.0204 - val_mean_absolute_error: 0.0997
# Epoch 123/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.0488 - root_mean_squared_error: 0.0488 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0312 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1420 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0981
# Epoch 124/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0503 - root_mean_squared_error: 0.0503 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0321 - val_loss: 0.1499 - val_root_mean_squared_error: 0.1498 - val_mean_squared_error: 0.0225 - val_mean_absolute_error: 0.1037
# Epoch 125/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0518 - root_mean_squared_error: 0.0518 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0337 - val_loss: 0.1376 - val_root_mean_squared_error: 0.1378 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.0973
# Epoch 126/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0525 - root_mean_squared_error: 0.0525 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0338 - val_loss: 0.1469 - val_root_mean_squared_error: 0.1469 - val_mean_squared_error: 0.0217 - val_mean_absolute_error: 0.1022
# Epoch 127/1000
# 18389/18389 [==============================] - 3s 178us/sample - loss: 0.0510 - root_mean_squared_error: 0.0510 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0330 - val_loss: 0.1440 - val_root_mean_squared_error: 0.1441 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0977
# Epoch 128/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0512 - root_mean_squared_error: 0.0512 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0327 - val_loss: 0.1514 - val_root_mean_squared_error: 0.1514 - val_mean_squared_error: 0.0230 - val_mean_absolute_error: 0.1026
# Epoch 129/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0560 - root_mean_squared_error: 0.0561 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0355 - val_loss: 0.1417 - val_root_mean_squared_error: 0.1416 - val_mean_squared_error: 0.0201 - val_mean_absolute_error: 0.0981
# Epoch 130/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0537 - root_mean_squared_error: 0.0537 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0344 - val_loss: 0.1394 - val_root_mean_squared_error: 0.1394 - val_mean_squared_error: 0.0195 - val_mean_absolute_error: 0.0988
# Epoch 131/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0511 - root_mean_squared_error: 0.0511 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0330 - val_loss: 0.1440 - val_root_mean_squared_error: 0.1442 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.0988
# Epoch 132/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0491 - root_mean_squared_error: 0.0491 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0318 - val_loss: 0.1502 - val_root_mean_squared_error: 0.1502 - val_mean_squared_error: 0.0226 - val_mean_absolute_error: 0.0978
# Epoch 133/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0487 - root_mean_squared_error: 0.0487 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0311 - val_loss: 0.1486 - val_root_mean_squared_error: 0.1486 - val_mean_squared_error: 0.0222 - val_mean_absolute_error: 0.1013
# Epoch 134/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0488 - root_mean_squared_error: 0.0488 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0315 - val_loss: 0.1465 - val_root_mean_squared_error: 0.1466 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.1028
# Epoch 135/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0475 - root_mean_squared_error: 0.0475 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0309 - val_loss: 0.1418 - val_root_mean_squared_error: 0.1419 - val_mean_squared_error: 0.0202 - val_mean_absolute_error: 0.0989
# Epoch 136/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0478 - root_mean_squared_error: 0.0478 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0305 - val_loss: 0.1430 - val_root_mean_squared_error: 0.1430 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.0974
# Epoch 137/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0475 - root_mean_squared_error: 0.0475 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0304 - val_loss: 0.1433 - val_root_mean_squared_error: 0.1435 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0967
# Epoch 138/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0485 - root_mean_squared_error: 0.0485 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0313 - val_loss: 0.1416 - val_root_mean_squared_error: 0.1415 - val_mean_squared_error: 0.0201 - val_mean_absolute_error: 0.1004
# Epoch 139/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.0472 - root_mean_squared_error: 0.0472 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0305 - val_loss: 0.1432 - val_root_mean_squared_error: 0.1432 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.1024
# Epoch 140/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0490 - root_mean_squared_error: 0.0490 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0318 - val_loss: 0.1467 - val_root_mean_squared_error: 0.1468 - val_mean_squared_error: 0.0216 - val_mean_absolute_error: 0.1036
# Epoch 141/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0497 - root_mean_squared_error: 0.0497 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0317 - val_loss: 0.1491 - val_root_mean_squared_error: 0.1493 - val_mean_squared_error: 0.0223 - val_mean_absolute_error: 0.1011
# Epoch 142/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0496 - root_mean_squared_error: 0.0496 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0320 - val_loss: 0.1394 - val_root_mean_squared_error: 0.1391 - val_mean_squared_error: 0.0195 - val_mean_absolute_error: 0.0951
# Epoch 143/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0525 - root_mean_squared_error: 0.0525 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0330 - val_loss: 0.1400 - val_root_mean_squared_error: 0.1401 - val_mean_squared_error: 0.0197 - val_mean_absolute_error: 0.0978
# Epoch 144/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0494 - root_mean_squared_error: 0.0495 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0317 - val_loss: 0.1391 - val_root_mean_squared_error: 0.1391 - val_mean_squared_error: 0.0194 - val_mean_absolute_error: 0.1009
# Epoch 145/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0500 - root_mean_squared_error: 0.0500 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0322 - val_loss: 0.1398 - val_root_mean_squared_error: 0.1396 - val_mean_squared_error: 0.0196 - val_mean_absolute_error: 0.1000
# Epoch 146/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0477 - root_mean_squared_error: 0.0477 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0307 - val_loss: 0.1443 - val_root_mean_squared_error: 0.1445 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.1049
# Epoch 147/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0477 - root_mean_squared_error: 0.0477 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0308 - val_loss: 0.1483 - val_root_mean_squared_error: 0.1482 - val_mean_squared_error: 0.0221 - val_mean_absolute_error: 0.1007
# Epoch 148/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0466 - root_mean_squared_error: 0.0466 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0300 - val_loss: 0.1415 - val_root_mean_squared_error: 0.1414 - val_mean_squared_error: 0.0201 - val_mean_absolute_error: 0.1011
# Epoch 149/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0466 - root_mean_squared_error: 0.0466 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0297 - val_loss: 0.1463 - val_root_mean_squared_error: 0.1464 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.1032
# Epoch 150/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0448 - root_mean_squared_error: 0.0449 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0286 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1421 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.1017
# Epoch 151/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0453 - root_mean_squared_error: 0.0453 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0288 - val_loss: 0.1442 - val_root_mean_squared_error: 0.1443 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.1006
# Epoch 152/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0448 - root_mean_squared_error: 0.0448 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0285 - val_loss: 0.1402 - val_root_mean_squared_error: 0.1403 - val_mean_squared_error: 0.0197 - val_mean_absolute_error: 0.0969
# Epoch 153/1000
# 18389/18389 [==============================] - 3s 177us/sample - loss: 0.0446 - root_mean_squared_error: 0.0446 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0284 - val_loss: 0.1436 - val_root_mean_squared_error: 0.1434 - val_mean_squared_error: 0.0207 - val_mean_absolute_error: 0.1001
# Epoch 154/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0447 - root_mean_squared_error: 0.0447 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0288 - val_loss: 0.1398 - val_root_mean_squared_error: 0.1400 - val_mean_squared_error: 0.0196 - val_mean_absolute_error: 0.0980
# Epoch 155/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0448 - root_mean_squared_error: 0.0448 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0284 - val_loss: 0.1433 - val_root_mean_squared_error: 0.1430 - val_mean_squared_error: 0.0206 - val_mean_absolute_error: 0.0995
# Epoch 156/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0450 - root_mean_squared_error: 0.0450 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0287 - val_loss: 0.1430 - val_root_mean_squared_error: 0.1430 - val_mean_squared_error: 0.0205 - val_mean_absolute_error: 0.1025
# Epoch 157/1000
# 18389/18389 [==============================] - 3s 177us/sample - loss: 0.0449 - root_mean_squared_error: 0.0449 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0288 - val_loss: 0.1441 - val_root_mean_squared_error: 0.1440 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.1044
# Epoch 158/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0439 - root_mean_squared_error: 0.0439 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0280 - val_loss: 0.1488 - val_root_mean_squared_error: 0.1486 - val_mean_squared_error: 0.0222 - val_mean_absolute_error: 0.1067
# Epoch 159/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0475 - root_mean_squared_error: 0.0475 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0299 - val_loss: 0.1518 - val_root_mean_squared_error: 0.1516 - val_mean_squared_error: 0.0231 - val_mean_absolute_error: 0.1077
# Epoch 160/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0514 - root_mean_squared_error: 0.0514 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0325 - val_loss: 0.1499 - val_root_mean_squared_error: 0.1496 - val_mean_squared_error: 0.0226 - val_mean_absolute_error: 0.1048
# Epoch 161/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0480 - root_mean_squared_error: 0.0480 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0307 - val_loss: 0.1530 - val_root_mean_squared_error: 0.1528 - val_mean_squared_error: 0.0235 - val_mean_absolute_error: 0.1070
# Epoch 162/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0477 - root_mean_squared_error: 0.0477 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0305 - val_loss: 0.1480 - val_root_mean_squared_error: 0.1479 - val_mean_squared_error: 0.0220 - val_mean_absolute_error: 0.1060
# Epoch 163/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0456 - root_mean_squared_error: 0.0456 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0294 - val_loss: 0.1565 - val_root_mean_squared_error: 0.1564 - val_mean_squared_error: 0.0246 - val_mean_absolute_error: 0.1058
# Epoch 164/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0452 - root_mean_squared_error: 0.0452 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0296 - val_loss: 0.1506 - val_root_mean_squared_error: 0.1504 - val_mean_squared_error: 0.0227 - val_mean_absolute_error: 0.1015
# Epoch 165/1000
# 18389/18389 [==============================] - 3s 177us/sample - loss: 0.0444 - root_mean_squared_error: 0.0444 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0288 - val_loss: 0.1466 - val_root_mean_squared_error: 0.1468 - val_mean_squared_error: 0.0216 - val_mean_absolute_error: 0.1018
# Epoch 166/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0448 - root_mean_squared_error: 0.0448 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0291 - val_loss: 0.1462 - val_root_mean_squared_error: 0.1462 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.1002
# Epoch 167/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0455 - root_mean_squared_error: 0.0455 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0298 - val_loss: 0.1421 - val_root_mean_squared_error: 0.1420 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.0992
# Epoch 168/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0459 - root_mean_squared_error: 0.0459 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0298 - val_loss: 0.1452 - val_root_mean_squared_error: 0.1451 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.1017
# Epoch 169/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0469 - root_mean_squared_error: 0.0469 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0309 - val_loss: 0.1463 - val_root_mean_squared_error: 0.1463 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.1037
# Epoch 170/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0461 - root_mean_squared_error: 0.0461 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0302 - val_loss: 0.1399 - val_root_mean_squared_error: 0.1399 - val_mean_squared_error: 0.0196 - val_mean_absolute_error: 0.0986
# Epoch 171/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0469 - root_mean_squared_error: 0.0469 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0307 - val_loss: 0.1452 - val_root_mean_squared_error: 0.1450 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.1038
# Epoch 172/1000
# 18389/18389 [==============================] - 3s 176us/sample - loss: 0.0472 - root_mean_squared_error: 0.0472 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0313 - val_loss: 0.1445 - val_root_mean_squared_error: 0.1445 - val_mean_squared_error: 0.0209 - val_mean_absolute_error: 0.1009
# Epoch 173/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0455 - root_mean_squared_error: 0.0455 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0296 - val_loss: 0.1458 - val_root_mean_squared_error: 0.1458 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.1032
# Epoch 174/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0463 - root_mean_squared_error: 0.0463 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0294 - val_loss: 0.1466 - val_root_mean_squared_error: 0.1464 - val_mean_squared_error: 0.0216 - val_mean_absolute_error: 0.1064
# Epoch 175/1000
# 18389/18389 [==============================] - 3s 170us/sample - loss: 0.0477 - root_mean_squared_error: 0.0478 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0307 - val_loss: 0.1500 - val_root_mean_squared_error: 0.1500 - val_mean_squared_error: 0.0226 - val_mean_absolute_error: 0.1085
# Epoch 176/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0464 - root_mean_squared_error: 0.0464 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0297 - val_loss: 0.1440 - val_root_mean_squared_error: 0.1441 - val_mean_squared_error: 0.0208 - val_mean_absolute_error: 0.1049
# Epoch 177/1000
# 18389/18389 [==============================] - 3s 171us/sample - loss: 0.0451 - root_mean_squared_error: 0.0451 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0291 - val_loss: 0.1459 - val_root_mean_squared_error: 0.1457 - val_mean_squared_error: 0.0213 - val_mean_absolute_error: 0.1060
# Epoch 178/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0431 - root_mean_squared_error: 0.0431 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0277 - val_loss: 0.1422 - val_root_mean_squared_error: 0.1422 - val_mean_squared_error: 0.0203 - val_mean_absolute_error: 0.1040
# Epoch 179/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0435 - root_mean_squared_error: 0.0435 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0283 - val_loss: 0.1465 - val_root_mean_squared_error: 0.1464 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.1042
# Epoch 180/1000
# 18389/18389 [==============================] - 3s 174us/sample - loss: 0.0447 - root_mean_squared_error: 0.0447 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0289 - val_loss: 0.1465 - val_root_mean_squared_error: 0.1464 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.1084
# Epoch 181/1000
# 18389/18389 [==============================] - 3s 175us/sample - loss: 0.0453 - root_mean_squared_error: 0.0453 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0293 - val_loss: 0.1452 - val_root_mean_squared_error: 0.1453 - val_mean_squared_error: 0.0212 - val_mean_absolute_error: 0.1061
# Epoch 182/1000
# 18389/18389 [==============================] - 3s 172us/sample - loss: 0.0444 - root_mean_squared_error: 0.0444 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0288 - val_loss: 0.1462 - val_root_mean_squared_error: 0.1460 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.1083
# Epoch 183/1000
# 18389/18389 [==============================] - 3s 177us/sample - loss: 0.0435 - root_mean_squared_error: 0.0435 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0280 - val_loss: 0.1464 - val_root_mean_squared_error: 0.1464 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.1055
# Epoch 184/1000
# 18389/18389 [==============================] - 3s 177us/sample - loss: 0.0437 - root_mean_squared_error: 0.0437 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0284 - val_loss: 0.1534 - val_root_mean_squared_error: 0.1535 - val_mean_squared_error: 0.0236 - val_mean_absolute_error: 0.1124
# Epoch 185/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0440 - root_mean_squared_error: 0.0440 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0285 - val_loss: 0.1540 - val_root_mean_squared_error: 0.1539 - val_mean_squared_error: 0.0238 - val_mean_absolute_error: 0.1150
# Epoch 186/1000
# 18389/18389 [==============================] - 3s 173us/sample - loss: 0.0432 - root_mean_squared_error: 0.0432 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0280 - val_loss: 0.1543 - val_root_mean_squared_error: 0.1542 - val_mean_squared_error: 0.0239 - val_mean_absolute_error: 0.1129
# Wall time: 9min 57s

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8)) 
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('PV_BasicCNN_TrainingandValidation Loss.png')
plt.show()

#print(get_flops(model))

# %%
trainPredict = model.predict(trX, batch_size=batch_size)
validPredict = model.predict(vaX, batch_size=batch_size)
testPredict = model.predict(teX, batch_size=batch_size)

# %%
tePredict = testPredict.reshape([-1])
testY = teY.reshape([-1])

np.savetxt('PV_BasicCNN_testPredict.txt', tePredict)
 
print('Error Test Score > RMSE == ', np.sqrt(np.mean(np.square(testY-tePredict))), ' MAE == ', mean_absolute_error(testY, tePredict))
# Out:
# Error Test Score > RMSE ==  0.14206655148631953  MAE ==  0.10672405784302902

# %%
plt.figure(figsize=(16,8)) 
plt.plot(tePredict[0:300])
plt.plot(testY[0:300])
plt.ylabel('Value')
plt.xlabel('time(h)')
plt.legend(['tePredict', 'testY'], loc='upper left')
plt.show()
