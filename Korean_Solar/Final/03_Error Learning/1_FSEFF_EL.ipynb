# %%
import tensorflow as tf
import pandas as pd

tf.compat.v1.disable_v2_behavior()

import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout
from scipy import signal
import openpyxl
import seaborn as sns
from keijzer import *
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply
from tensorflow.keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from tensorflow.keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
from tensorflow.keras.utils import plot_model
from tensorflow.keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math
# Out:
# WARNING:tensorflow:From C:\Users\Smartgrid_ML\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
PV = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/seobu_pv.csv'
pv_source = pd.read_csv(PV, encoding='CP949')
pv_source = pd.DataFrame(pv_source)
pv_source = pv_source.iloc[0:1277, :]
pv_data = np.array(pv_source)

weather_17 = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/mokpo_2017.csv'
weather_18 = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/mokpo_2018.csv'
weather_19 = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/mokpo_2019.csv'
weather_20 = 'C:/Users/Smartgrid_ML/Documents/KMS/btm_data/korean_data/pv/mokpo_2020.csv'

weather_17 = pd.read_csv(weather_17, encoding='CP949')
weather_18 = pd.read_csv(weather_18, encoding='CP949')
weather_19 = pd.read_csv(weather_19, encoding='CP949')
weather_20 = pd.read_csv(weather_20, encoding='CP949')
weather = pd.concat([weather_17,weather_18,weather_19,weather_20])
weather_data = np.array(weather)

pv_data = np.nan_to_num(pv_data)
weather_data = np.nan_to_num(weather_data)
pv_dat = pv_data[:, 2:]
weather_dat = weather_data[:, 3:]
pv_dat = pv_dat.reshape(-1,1)

dataset = np.hstack([pv_dat, weather_dat])
index = ['Measured PV', 'Temperature C', 'Rainfall', 'Wind speed', 'Wind direction', 'Humidity', 'Air pressure', 'Dew point C', 'Sunshine', 'Solar radiation', 'Snowfall', 'Cloud cover', 'Surface temp C']

df = pd.DataFrame(dataset, columns=index)
df.head()
df = df.fillna(0)
min_max_scaler = preprocessing.MinMaxScaler()
norm_df = pd.DataFrame(min_max_scaler.fit_transform(df), 
                             columns=df.columns, 
                             index=df.index)
norm_df.head()
# Out:
#    Measured PV  Temperature C  Rainfall  Wind speed  Wind direction  Humidity  \
# 0          0.0       0.354298       0.0    0.023256        0.000000      0.89
# 1          0.0       0.339623       0.0    0.104651        0.444444      0.93
# 2          0.0       0.320755       0.0    0.046512        0.388889      0.93
# 3          0.0       0.303983       0.0    0.087209        0.444444      0.94
# 4          0.0       0.287212       0.0    0.104651        0.444444      0.95
#
#    Air pressure  Dew point C  Sunshine  Solar radiation  Snowfall  \
# 0      0.189696     0.444681       0.0              0.0       0.0
# 1      0.189696     0.442553       0.0              0.0       0.0
# 2      0.177986     0.423404       0.0              0.0       0.0
# 3      0.170960     0.410638       0.0              0.0       0.0
# 4      0.161593     0.395745       0.0              0.0       0.0
#
#    Cloud cover  Surface temp C
# 0          0.6        0.141834
# 1          0.0        0.117479
# 2          0.0        0.103152
# 3          0.0        0.095989
# 4          0.0        0.088825

# %%
import seaborn as sns
from keijzer import *

fig = create_corr_matrix(norm_df, 'Correlation Matrix of all components in dataset', True, size=(25,25))
fig.savefig('correlation_matrix.png')
# Out:
# C:\Users\Smartgrid_ML\Documents\KMS\btm_data\Korean_Solar\Final\03_Error Learning\keijzer.py:70: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Saving heatmap

# %%
norm_df = np.array(norm_df)
norm_df2 = norm_df[:,(0, 1, 4, 5, 6, 8, 9, 11, 12)]

# %%
def get_flops(model):
    run_meta = tf.RunMetadata()
    opts = tf.profiler.ProfileOptionBuilder.float_operation()

    # We use the Keras session graph in the call to the profiler.
    flops = tf.profiler.profile(graph=K.get_session().graph,
                                run_meta=run_meta, cmd='op', options=opts)

    return flops.total_float_ops  # Prints the "flops" of the model.

def create_dataset(dataset, timesteps, output_timesteps):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps):(i+timesteps+output_timesteps), :])
    return np.array(dataX), np.array(dataY)

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
timesteps = 30
output_timesteps = 12

X, Y = create_dataset(norm_df2, timesteps, output_timesteps)

trX = X[:18389, :, :]
vaX = X[18389:21447, :, :]
teX = X[21447:, :, :]
trY = Y[:18389, :, 0]
vaY = Y[18389:21447, :, 0]
teY = Y[21447:, :, 0]

print(trX.shape)
print(trY.shape)
print(teX.shape)
# Out:
# (18389, 30, 9)
# (18389, 12)
# (9158, 30, 9)

# %%
with tf.device('/gpu:0'):
    alpha=1.05
    gamma=1.2
    beta = 1.15011
    num_features = 9
    hfilters = 256
    hkernel_size1 = 2
    hkernel_size2 = 4
    visible1 = Input(shape=(timesteps, num_features))
    per1 = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(per1)
    den1b = Dense(timesteps, activation='sigmoid')(per1)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res01 = Add()([d1, visible1])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res02 = Add()([d1, res01])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res03 = Add()([d1, res02])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=16)(d1)  
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res04 =Add()([d1, res03])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=16)(res04)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=32)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res05 = Add()([d1, res04])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=32)(res05) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=16)(d1)   
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res06 = Add()([d1, res05])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=16)(res06) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res07 = Add()([d1, res06])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res07)  
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res08 = Add()([d1, res07])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res08)   
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)  
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res09 = Add()([d1, res08])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res09) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res10 = Add()([d1, res09])   # 
    
    print('res10 :', res10.shape)  # (None, 24, 11) 
    
    out = Conv1D(512, 1, padding='same', activation='relu')(res10)   # 256, 11X10=110  
    out = Dropout(0.2)(out)   
    
    out = Conv1D(256, 1, padding='same', activation='relu')(out) # 512,  110X5=550
    out = Dropout(0.2)(out)  
    
    out = GlobalAveragePooling1D()(out) # pool_size=2, strides=1
    
    out = Dense(output_timesteps)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
    
    model.compile(loss=root_mean_squared_error, optimizer='adam', metrics=[root_mean_squared_error, 'mse', 'mae'])
    early_stopping =EarlyStopping(monitor='val_loss', patience=100)
    batch_size = 100
    epochs = 1000

    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# res10 : (?, 30, 9)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 30, 9)]      0
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 9, 30)        0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 9, 30)        930         permute_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 9, 30)        930         permute_1[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 9, 30)        0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 30, 9)        0           multiply_22[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 30, 9)        0           input_2[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 30, 269)      5111        multiply_23[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 30, 269)      0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 30, 269)      0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 30, 269)      0           activation_40[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 30, 9)        12114       multiply_24[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 30, 9)        0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 30, 9)        0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 30, 9)        0           activation_42[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 30, 9)        0           multiply_25[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 30, 269)      5111        add_10[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 30, 269)      0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 30, 269)      0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 30, 269)      0           activation_44[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 30, 9)        12114       multiply_26[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 30, 9)        0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 30, 9)        0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 30, 9)        0           activation_46[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 30, 9)        0           multiply_27[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 30, 269)      5111        add_11[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 30, 269)      0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 30, 269)      0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 30, 269)      0           activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 30, 9)        12114       multiply_28[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 30, 9)        0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 30, 9)        0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 30, 9)        0           activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 30, 9)        0           multiply_29[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 30, 269)      5111        add_12[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 30, 269)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 30, 269)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 30, 269)      0           activation_52[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 30, 9)        12114       multiply_30[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 30, 9)        0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 30, 9)        0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 30, 9)        0           activation_54[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 30, 9)        0           multiply_31[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 30, 269)      5111        add_13[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 30, 269)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 30, 269)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 30, 269)      0           activation_56[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 30, 9)        12114       multiply_32[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 30, 9)        0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 30, 9)        0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 30, 9)        0           activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 30, 9)        0           multiply_33[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 30, 269)      5111        add_14[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 30, 269)      0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 30, 269)      0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 30, 269)      0           activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 30, 9)        12114       multiply_34[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 30, 9)        0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 30, 9)        0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 30, 9)        0           activation_62[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 30, 9)        0           multiply_35[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 30, 269)      5111        add_15[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 30, 269)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 30, 269)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 30, 269)      0           activation_64[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 30, 9)        12114       multiply_36[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 30, 9)        0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 30, 9)        0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 30, 9)        0           activation_66[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 30, 9)        0           multiply_37[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 30, 269)      5111        add_16[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 30, 269)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 30, 269)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 30, 269)      0           activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 30, 9)        12114       multiply_38[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 30, 9)        0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 30, 9)        0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 30, 9)        0           activation_70[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 30, 9)        0           multiply_39[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 30, 269)      5111        add_17[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 30, 269)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 30, 269)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 30, 269)      0           activation_72[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 30, 9)        12114       multiply_40[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 30, 9)        0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 30, 9)        0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 30, 9)        0           activation_74[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 30, 9)        0           multiply_41[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 30, 269)      5111        add_18[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 30, 269)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 30, 269)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 30, 269)      0           activation_76[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 30, 9)        12114       multiply_42[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 30, 9)        0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 30, 9)        0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 30, 9)        0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 30, 9)        0           multiply_43[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 30, 512)      5120        add_19[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 30, 512)      0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 30, 256)      131328      dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 30, 256)      0           conv1d_43[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 256)          0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 12)           3084        global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 313,642
# Trainable params: 313,642
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
    # %%time
    hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Train on 18389 samples, validate on 3058 samples
# Epoch 1/1000
# 18389/18389 [==============================] - ETA: 0s - loss: 0.1699 - root_mean_squared_error: 0.1699 - mean_squared_error: 0.0315 - mean_absolute_error: 0.1241
# C:\Users\Smartgrid_ML\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\keras\engine\training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 18389/18389 [==============================] - 9s 507us/sample - loss: 0.1699 - root_mean_squared_error: 0.1699 - mean_squared_error: 0.0315 - mean_absolute_error: 0.1241 - val_loss: 0.1523 - val_root_mean_squared_error: 0.1525 - val_mean_squared_error: 0.0233 - val_mean_absolute_error: 0.1005
# Epoch 2/1000
# 18389/18389 [==============================] - 6s 320us/sample - loss: 0.1319 - root_mean_squared_error: 0.1319 - mean_squared_error: 0.0183 - mean_absolute_error: 0.0857 - val_loss: 0.1409 - val_root_mean_squared_error: 0.1411 - val_mean_squared_error: 0.0199 - val_mean_absolute_error: 0.0895
# Epoch 3/1000
# 18389/18389 [==============================] - 6s 321us/sample - loss: 0.1240 - root_mean_squared_error: 0.1240 - mean_squared_error: 0.0162 - mean_absolute_error: 0.0787 - val_loss: 0.1409 - val_root_mean_squared_error: 0.1412 - val_mean_squared_error: 0.0199 - val_mean_absolute_error: 0.0891
# Epoch 4/1000
# 18389/18389 [==============================] - 6s 322us/sample - loss: 0.1199 - root_mean_squared_error: 0.1199 - mean_squared_error: 0.0151 - mean_absolute_error: 0.0751 - val_loss: 0.1460 - val_root_mean_squared_error: 0.1458 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0907
# Epoch 5/1000
# 18389/18389 [==============================] - 6s 321us/sample - loss: 0.1176 - root_mean_squared_error: 0.1176 - mean_squared_error: 0.0145 - mean_absolute_error: 0.0729 - val_loss: 0.1459 - val_root_mean_squared_error: 0.1456 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0900
# Epoch 6/1000
# 18389/18389 [==============================] - 6s 321us/sample - loss: 0.1158 - root_mean_squared_error: 0.1159 - mean_squared_error: 0.0141 - mean_absolute_error: 0.0714 - val_loss: 0.1485 - val_root_mean_squared_error: 0.1484 - val_mean_squared_error: 0.0222 - val_mean_absolute_error: 0.0917
# Epoch 7/1000
# 18389/18389 [==============================] - 6s 323us/sample - loss: 0.1148 - root_mean_squared_error: 0.1149 - mean_squared_error: 0.0139 - mean_absolute_error: 0.0706 - val_loss: 0.1544 - val_root_mean_squared_error: 0.1544 - val_mean_squared_error: 0.0239 - val_mean_absolute_error: 0.0943
# Epoch 8/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.1137 - root_mean_squared_error: 0.1137 - mean_squared_error: 0.0136 - mean_absolute_error: 0.0699 - val_loss: 0.1564 - val_root_mean_squared_error: 0.1562 - val_mean_squared_error: 0.0245 - val_mean_absolute_error: 0.0962
# Epoch 9/1000
# 18389/18389 [==============================] - 6s 319us/sample - loss: 0.1129 - root_mean_squared_error: 0.1129 - mean_squared_error: 0.0134 - mean_absolute_error: 0.0692 - val_loss: 0.1563 - val_root_mean_squared_error: 0.1564 - val_mean_squared_error: 0.0245 - val_mean_absolute_error: 0.0950
# Epoch 10/1000
# 18389/18389 [==============================] - 6s 318us/sample - loss: 0.1132 - root_mean_squared_error: 0.1132 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0693 - val_loss: 0.1621 - val_root_mean_squared_error: 0.1624 - val_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0989
# Epoch 11/1000
# 18389/18389 [==============================] - 6s 323us/sample - loss: 0.1124 - root_mean_squared_error: 0.1125 - mean_squared_error: 0.0133 - mean_absolute_error: 0.0687 - val_loss: 0.1682 - val_root_mean_squared_error: 0.1679 - val_mean_squared_error: 0.0284 - val_mean_absolute_error: 0.1012
# Epoch 12/1000
# 18389/18389 [==============================] - 6s 319us/sample - loss: 0.1111 - root_mean_squared_error: 0.1111 - mean_squared_error: 0.0130 - mean_absolute_error: 0.0678 - val_loss: 0.1732 - val_root_mean_squared_error: 0.1730 - val_mean_squared_error: 0.0302 - val_mean_absolute_error: 0.1045
# Epoch 13/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.1113 - root_mean_squared_error: 0.1114 - mean_squared_error: 0.0130 - mean_absolute_error: 0.0685 - val_loss: 0.1725 - val_root_mean_squared_error: 0.1723 - val_mean_squared_error: 0.0299 - val_mean_absolute_error: 0.1042
# Epoch 14/1000
# 18389/18389 [==============================] - 6s 319us/sample - loss: 0.1107 - root_mean_squared_error: 0.1107 - mean_squared_error: 0.0129 - mean_absolute_error: 0.0678 - val_loss: 0.1633 - val_root_mean_squared_error: 0.1633 - val_mean_squared_error: 0.0267 - val_mean_absolute_error: 0.0975
# Epoch 15/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.1112 - root_mean_squared_error: 0.1113 - mean_squared_error: 0.0130 - mean_absolute_error: 0.0680 - val_loss: 0.1881 - val_root_mean_squared_error: 0.1880 - val_mean_squared_error: 0.0355 - val_mean_absolute_error: 0.1096
# Epoch 16/1000
# 18389/18389 [==============================] - 6s 318us/sample - loss: 0.1099 - root_mean_squared_error: 0.1100 - mean_squared_error: 0.0127 - mean_absolute_error: 0.0672 - val_loss: 0.1910 - val_root_mean_squared_error: 0.1908 - val_mean_squared_error: 0.0366 - val_mean_absolute_error: 0.1108
# Epoch 17/1000
# 18389/18389 [==============================] - 6s 322us/sample - loss: 0.1103 - root_mean_squared_error: 0.1103 - mean_squared_error: 0.0128 - mean_absolute_error: 0.0676 - val_loss: 0.1780 - val_root_mean_squared_error: 0.1778 - val_mean_squared_error: 0.0318 - val_mean_absolute_error: 0.1047
# Epoch 18/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.1081 - root_mean_squared_error: 0.1081 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0666 - val_loss: 0.1665 - val_root_mean_squared_error: 0.1665 - val_mean_squared_error: 0.0279 - val_mean_absolute_error: 0.1022
# Epoch 19/1000
# 18389/18389 [==============================] - 6s 323us/sample - loss: 0.1110 - root_mean_squared_error: 0.1111 - mean_squared_error: 0.0130 - mean_absolute_error: 0.0676 - val_loss: 0.1799 - val_root_mean_squared_error: 0.1797 - val_mean_squared_error: 0.0325 - val_mean_absolute_error: 0.1041
# Epoch 20/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.1091 - root_mean_squared_error: 0.1091 - mean_squared_error: 0.0124 - mean_absolute_error: 0.0671 - val_loss: 0.1761 - val_root_mean_squared_error: 0.1759 - val_mean_squared_error: 0.0312 - val_mean_absolute_error: 0.1127
# Epoch 21/1000
# 18389/18389 [==============================] - 6s 319us/sample - loss: 0.1097 - root_mean_squared_error: 0.1097 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0679 - val_loss: 0.1825 - val_root_mean_squared_error: 0.1823 - val_mean_squared_error: 0.0334 - val_mean_absolute_error: 0.1069
# Epoch 22/1000
# 18389/18389 [==============================] - 6s 316us/sample - loss: 0.1096 - root_mean_squared_error: 0.1096 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0666 - val_loss: 0.1900 - val_root_mean_squared_error: 0.1901 - val_mean_squared_error: 0.0364 - val_mean_absolute_error: 0.1098
# Epoch 23/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.1086 - root_mean_squared_error: 0.1086 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0662 - val_loss: 0.1809 - val_root_mean_squared_error: 0.1809 - val_mean_squared_error: 0.0329 - val_mean_absolute_error: 0.1063
# Epoch 24/1000
# 18389/18389 [==============================] - 6s 322us/sample - loss: 0.1078 - root_mean_squared_error: 0.1078 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0655 - val_loss: 0.1843 - val_root_mean_squared_error: 0.1840 - val_mean_squared_error: 0.0342 - val_mean_absolute_error: 0.1081
# Epoch 25/1000
# 18389/18389 [==============================] - 6s 316us/sample - loss: 0.1086 - root_mean_squared_error: 0.1086 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0668 - val_loss: 0.1821 - val_root_mean_squared_error: 0.1820 - val_mean_squared_error: 0.0334 - val_mean_absolute_error: 0.1099
# Epoch 26/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.1085 - root_mean_squared_error: 0.1085 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0662 - val_loss: 0.1708 - val_root_mean_squared_error: 0.1705 - val_mean_squared_error: 0.0293 - val_mean_absolute_error: 0.0999
# Epoch 27/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.1078 - root_mean_squared_error: 0.1078 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0663 - val_loss: 0.1828 - val_root_mean_squared_error: 0.1827 - val_mean_squared_error: 0.0335 - val_mean_absolute_error: 0.1081
# Epoch 28/1000
# 18389/18389 [==============================] - 6s 318us/sample - loss: 0.1084 - root_mean_squared_error: 0.1084 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0665 - val_loss: 0.1695 - val_root_mean_squared_error: 0.1695 - val_mean_squared_error: 0.0289 - val_mean_absolute_error: 0.1068
# Epoch 29/1000
# 18389/18389 [==============================] - 6s 319us/sample - loss: 0.1125 - root_mean_squared_error: 0.1125 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0701 - val_loss: 0.1595 - val_root_mean_squared_error: 0.1599 - val_mean_squared_error: 0.0255 - val_mean_absolute_error: 0.0970
# Epoch 30/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.1094 - root_mean_squared_error: 0.1095 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0674 - val_loss: 0.1791 - val_root_mean_squared_error: 0.1794 - val_mean_squared_error: 0.0323 - val_mean_absolute_error: 0.1087
# Epoch 31/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.1085 - root_mean_squared_error: 0.1086 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0673 - val_loss: 0.1810 - val_root_mean_squared_error: 0.1811 - val_mean_squared_error: 0.0329 - val_mean_absolute_error: 0.1085
# Epoch 32/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.1071 - root_mean_squared_error: 0.1071 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0664 - val_loss: 0.1803 - val_root_mean_squared_error: 0.1803 - val_mean_squared_error: 0.0327 - val_mean_absolute_error: 0.1085
# Epoch 33/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.1083 - root_mean_squared_error: 0.1083 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0667 - val_loss: 0.1761 - val_root_mean_squared_error: 0.1760 - val_mean_squared_error: 0.0311 - val_mean_absolute_error: 0.1059
# Epoch 34/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.1069 - root_mean_squared_error: 0.1069 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0666 - val_loss: 0.1732 - val_root_mean_squared_error: 0.1732 - val_mean_squared_error: 0.0301 - val_mean_absolute_error: 0.1039
# Epoch 35/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.1075 - root_mean_squared_error: 0.1075 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0665 - val_loss: 0.1790 - val_root_mean_squared_error: 0.1791 - val_mean_squared_error: 0.0323 - val_mean_absolute_error: 0.1082
# Epoch 36/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.1073 - root_mean_squared_error: 0.1074 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0668 - val_loss: 0.1740 - val_root_mean_squared_error: 0.1738 - val_mean_squared_error: 0.0304 - val_mean_absolute_error: 0.1074
# Epoch 37/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.1058 - root_mean_squared_error: 0.1058 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0654 - val_loss: 0.1824 - val_root_mean_squared_error: 0.1823 - val_mean_squared_error: 0.0334 - val_mean_absolute_error: 0.1105
# Epoch 38/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.1060 - root_mean_squared_error: 0.1060 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0662 - val_loss: 0.1761 - val_root_mean_squared_error: 0.1761 - val_mean_squared_error: 0.0311 - val_mean_absolute_error: 0.1087
# Epoch 39/1000
# 18389/18389 [==============================] - 6s 320us/sample - loss: 0.1044 - root_mean_squared_error: 0.1044 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0648 - val_loss: 0.1766 - val_root_mean_squared_error: 0.1768 - val_mean_squared_error: 0.0313 - val_mean_absolute_error: 0.1082
# Epoch 40/1000
# 18389/18389 [==============================] - 6s 316us/sample - loss: 0.1039 - root_mean_squared_error: 0.1039 - mean_squared_error: 0.0113 - mean_absolute_error: 0.0647 - val_loss: 0.1748 - val_root_mean_squared_error: 0.1750 - val_mean_squared_error: 0.0307 - val_mean_absolute_error: 0.1092
# Epoch 41/1000
# 18389/18389 [==============================] - 6s 320us/sample - loss: 0.1032 - root_mean_squared_error: 0.1032 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0641 - val_loss: 0.1763 - val_root_mean_squared_error: 0.1762 - val_mean_squared_error: 0.0312 - val_mean_absolute_error: 0.1097
# Epoch 42/1000
# 18389/18389 [==============================] - 6s 320us/sample - loss: 0.1030 - root_mean_squared_error: 0.1030 - mean_squared_error: 0.0111 - mean_absolute_error: 0.0642 - val_loss: 0.1743 - val_root_mean_squared_error: 0.1743 - val_mean_squared_error: 0.0305 - val_mean_absolute_error: 0.1059
# Epoch 43/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.1013 - root_mean_squared_error: 0.1013 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0629 - val_loss: 0.1790 - val_root_mean_squared_error: 0.1791 - val_mean_squared_error: 0.0322 - val_mean_absolute_error: 0.1109
# Epoch 44/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.1012 - root_mean_squared_error: 0.1012 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0631 - val_loss: 0.1794 - val_root_mean_squared_error: 0.1794 - val_mean_squared_error: 0.0323 - val_mean_absolute_error: 0.1157
# Epoch 45/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.0998 - root_mean_squared_error: 0.0998 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0623 - val_loss: 0.1811 - val_root_mean_squared_error: 0.1810 - val_mean_squared_error: 0.0330 - val_mean_absolute_error: 0.1179
# Epoch 46/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.1003 - root_mean_squared_error: 0.1003 - mean_squared_error: 0.0105 - mean_absolute_error: 0.0625 - val_loss: 0.1748 - val_root_mean_squared_error: 0.1750 - val_mean_squared_error: 0.0307 - val_mean_absolute_error: 0.1156
# Epoch 47/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.0995 - root_mean_squared_error: 0.0995 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0619 - val_loss: 0.1817 - val_root_mean_squared_error: 0.1818 - val_mean_squared_error: 0.0332 - val_mean_absolute_error: 0.1219
# Epoch 48/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.0990 - root_mean_squared_error: 0.0990 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0617 - val_loss: 0.1840 - val_root_mean_squared_error: 0.1841 - val_mean_squared_error: 0.0340 - val_mean_absolute_error: 0.1251
# Epoch 49/1000
# 18389/18389 [==============================] - 6s 320us/sample - loss: 0.0982 - root_mean_squared_error: 0.0982 - mean_squared_error: 0.0101 - mean_absolute_error: 0.0615 - val_loss: 0.1809 - val_root_mean_squared_error: 0.1808 - val_mean_squared_error: 0.0329 - val_mean_absolute_error: 0.1202
# Epoch 50/1000
# 18389/18389 [==============================] - 6s 311us/sample - loss: 0.0973 - root_mean_squared_error: 0.0973 - mean_squared_error: 0.0099 - mean_absolute_error: 0.0609 - val_loss: 0.1716 - val_root_mean_squared_error: 0.1717 - val_mean_squared_error: 0.0295 - val_mean_absolute_error: 0.1166
# Epoch 51/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0970 - root_mean_squared_error: 0.0970 - mean_squared_error: 0.0098 - mean_absolute_error: 0.0606 - val_loss: 0.1704 - val_root_mean_squared_error: 0.1705 - val_mean_squared_error: 0.0292 - val_mean_absolute_error: 0.1147
# Epoch 52/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0966 - root_mean_squared_error: 0.0966 - mean_squared_error: 0.0098 - mean_absolute_error: 0.0604 - val_loss: 0.1654 - val_root_mean_squared_error: 0.1655 - val_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.1115
# Epoch 53/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.0957 - root_mean_squared_error: 0.0957 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0597 - val_loss: 0.1600 - val_root_mean_squared_error: 0.1601 - val_mean_squared_error: 0.0257 - val_mean_absolute_error: 0.1084
# Epoch 54/1000
# 18389/18389 [==============================] - 6s 318us/sample - loss: 0.0948 - root_mean_squared_error: 0.0948 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0590 - val_loss: 0.1624 - val_root_mean_squared_error: 0.1625 - val_mean_squared_error: 0.0265 - val_mean_absolute_error: 0.1102
# Epoch 55/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.0946 - root_mean_squared_error: 0.0946 - mean_squared_error: 0.0094 - mean_absolute_error: 0.0589 - val_loss: 0.1607 - val_root_mean_squared_error: 0.1606 - val_mean_squared_error: 0.0259 - val_mean_absolute_error: 0.1097
# Epoch 56/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0942 - root_mean_squared_error: 0.0942 - mean_squared_error: 0.0093 - mean_absolute_error: 0.0588 - val_loss: 0.1576 - val_root_mean_squared_error: 0.1572 - val_mean_squared_error: 0.0250 - val_mean_absolute_error: 0.1075
# Epoch 57/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.0934 - root_mean_squared_error: 0.0934 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0582 - val_loss: 0.1598 - val_root_mean_squared_error: 0.1600 - val_mean_squared_error: 0.0256 - val_mean_absolute_error: 0.1086
# Epoch 58/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.0920 - root_mean_squared_error: 0.0920 - mean_squared_error: 0.0088 - mean_absolute_error: 0.0574 - val_loss: 0.1552 - val_root_mean_squared_error: 0.1551 - val_mean_squared_error: 0.0242 - val_mean_absolute_error: 0.1060
# Epoch 59/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.0915 - root_mean_squared_error: 0.0915 - mean_squared_error: 0.0087 - mean_absolute_error: 0.0571 - val_loss: 0.1519 - val_root_mean_squared_error: 0.1520 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.1025
# Epoch 60/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0910 - root_mean_squared_error: 0.0910 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0566 - val_loss: 0.1539 - val_root_mean_squared_error: 0.1538 - val_mean_squared_error: 0.0238 - val_mean_absolute_error: 0.1048
# Epoch 61/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0909 - root_mean_squared_error: 0.0910 - mean_squared_error: 0.0086 - mean_absolute_error: 0.0566 - val_loss: 0.1531 - val_root_mean_squared_error: 0.1532 - val_mean_squared_error: 0.0235 - val_mean_absolute_error: 0.1018
# Epoch 62/1000
# 18389/18389 [==============================] - 6s 316us/sample - loss: 0.0902 - root_mean_squared_error: 0.0902 - mean_squared_error: 0.0085 - mean_absolute_error: 0.0561 - val_loss: 0.1518 - val_root_mean_squared_error: 0.1521 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.1031
# Epoch 63/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0892 - root_mean_squared_error: 0.0892 - mean_squared_error: 0.0083 - mean_absolute_error: 0.0555 - val_loss: 0.1491 - val_root_mean_squared_error: 0.1489 - val_mean_squared_error: 0.0223 - val_mean_absolute_error: 0.0954
# Epoch 64/1000
# 18389/18389 [==============================] - 6s 316us/sample - loss: 0.0882 - root_mean_squared_error: 0.0882 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0548 - val_loss: 0.1552 - val_root_mean_squared_error: 0.1552 - val_mean_squared_error: 0.0242 - val_mean_absolute_error: 0.1036
# Epoch 65/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.0877 - root_mean_squared_error: 0.0877 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0544 - val_loss: 0.1520 - val_root_mean_squared_error: 0.1521 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.0998
# Epoch 66/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.0868 - root_mean_squared_error: 0.0868 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0538 - val_loss: 0.1581 - val_root_mean_squared_error: 0.1579 - val_mean_squared_error: 0.0251 - val_mean_absolute_error: 0.1056
# Epoch 67/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0870 - root_mean_squared_error: 0.0870 - mean_squared_error: 0.0079 - mean_absolute_error: 0.0540 - val_loss: 0.1495 - val_root_mean_squared_error: 0.1494 - val_mean_squared_error: 0.0225 - val_mean_absolute_error: 0.1002
# Epoch 68/1000
# 18389/18389 [==============================] - 6s 311us/sample - loss: 0.0858 - root_mean_squared_error: 0.0858 - mean_squared_error: 0.0077 - mean_absolute_error: 0.0532 - val_loss: 0.1505 - val_root_mean_squared_error: 0.1504 - val_mean_squared_error: 0.0228 - val_mean_absolute_error: 0.1010
# Epoch 69/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0852 - root_mean_squared_error: 0.0852 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0527 - val_loss: 0.1486 - val_root_mean_squared_error: 0.1483 - val_mean_squared_error: 0.0222 - val_mean_absolute_error: 0.0987
# Epoch 70/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.0847 - root_mean_squared_error: 0.0847 - mean_squared_error: 0.0075 - mean_absolute_error: 0.0523 - val_loss: 0.1483 - val_root_mean_squared_error: 0.1482 - val_mean_squared_error: 0.0221 - val_mean_absolute_error: 0.0982
# Epoch 71/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0840 - root_mean_squared_error: 0.0840 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0518 - val_loss: 0.1463 - val_root_mean_squared_error: 0.1461 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.0967
# Epoch 72/1000
# 18389/18389 [==============================] - 6s 318us/sample - loss: 0.0833 - root_mean_squared_error: 0.0834 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0514 - val_loss: 0.1487 - val_root_mean_squared_error: 0.1487 - val_mean_squared_error: 0.0223 - val_mean_absolute_error: 0.0965
# Epoch 73/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0836 - root_mean_squared_error: 0.0836 - mean_squared_error: 0.0073 - mean_absolute_error: 0.0514 - val_loss: 0.1499 - val_root_mean_squared_error: 0.1501 - val_mean_squared_error: 0.0226 - val_mean_absolute_error: 0.0969
# Epoch 74/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0842 - root_mean_squared_error: 0.0842 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0517 - val_loss: 0.1488 - val_root_mean_squared_error: 0.1491 - val_mean_squared_error: 0.0223 - val_mean_absolute_error: 0.0960
# Epoch 75/1000
# 18389/18389 [==============================] - 6s 318us/sample - loss: 0.0841 - root_mean_squared_error: 0.0841 - mean_squared_error: 0.0074 - mean_absolute_error: 0.0518 - val_loss: 0.1502 - val_root_mean_squared_error: 0.1501 - val_mean_squared_error: 0.0227 - val_mean_absolute_error: 0.0966
# Epoch 76/1000
# 18389/18389 [==============================] - 6s 316us/sample - loss: 0.0825 - root_mean_squared_error: 0.0825 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0507 - val_loss: 0.1530 - val_root_mean_squared_error: 0.1526 - val_mean_squared_error: 0.0235 - val_mean_absolute_error: 0.0979
# Epoch 77/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.0822 - root_mean_squared_error: 0.0823 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0505 - val_loss: 0.1507 - val_root_mean_squared_error: 0.1507 - val_mean_squared_error: 0.0228 - val_mean_absolute_error: 0.0966
# Epoch 78/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0823 - root_mean_squared_error: 0.0823 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0505 - val_loss: 0.1519 - val_root_mean_squared_error: 0.1515 - val_mean_squared_error: 0.0232 - val_mean_absolute_error: 0.0958
# Epoch 79/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0824 - root_mean_squared_error: 0.0824 - mean_squared_error: 0.0071 - mean_absolute_error: 0.0503 - val_loss: 0.1527 - val_root_mean_squared_error: 0.1524 - val_mean_squared_error: 0.0234 - val_mean_absolute_error: 0.0956
# Epoch 80/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0810 - root_mean_squared_error: 0.0810 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0495 - val_loss: 0.1574 - val_root_mean_squared_error: 0.1574 - val_mean_squared_error: 0.0249 - val_mean_absolute_error: 0.0997
# Epoch 81/1000
# 18389/18389 [==============================] - 6s 310us/sample - loss: 0.0806 - root_mean_squared_error: 0.0806 - mean_squared_error: 0.0068 - mean_absolute_error: 0.0493 - val_loss: 0.1463 - val_root_mean_squared_error: 0.1465 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.0929
# Epoch 82/1000
# 18389/18389 [==============================] - 6s 311us/sample - loss: 0.0793 - root_mean_squared_error: 0.0793 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0487 - val_loss: 0.1415 - val_root_mean_squared_error: 0.1416 - val_mean_squared_error: 0.0201 - val_mean_absolute_error: 0.0885
# Epoch 83/1000
# 18389/18389 [==============================] - 6s 311us/sample - loss: 0.0792 - root_mean_squared_error: 0.0792 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0487 - val_loss: 0.1406 - val_root_mean_squared_error: 0.1404 - val_mean_squared_error: 0.0199 - val_mean_absolute_error: 0.0899
# Epoch 84/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0794 - root_mean_squared_error: 0.0794 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0489 - val_loss: 0.1374 - val_root_mean_squared_error: 0.1376 - val_mean_squared_error: 0.0190 - val_mean_absolute_error: 0.0877
# Epoch 85/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.0791 - root_mean_squared_error: 0.0791 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0488 - val_loss: 0.1367 - val_root_mean_squared_error: 0.1367 - val_mean_squared_error: 0.0188 - val_mean_absolute_error: 0.0860
# Epoch 86/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.0794 - root_mean_squared_error: 0.0794 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0489 - val_loss: 0.1355 - val_root_mean_squared_error: 0.1354 - val_mean_squared_error: 0.0185 - val_mean_absolute_error: 0.0857
# Epoch 87/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.0782 - root_mean_squared_error: 0.0782 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0481 - val_loss: 0.1341 - val_root_mean_squared_error: 0.1340 - val_mean_squared_error: 0.0181 - val_mean_absolute_error: 0.0851
# Epoch 88/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0787 - root_mean_squared_error: 0.0787 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0484 - val_loss: 0.1345 - val_root_mean_squared_error: 0.1346 - val_mean_squared_error: 0.0182 - val_mean_absolute_error: 0.0834
# Epoch 89/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.0776 - root_mean_squared_error: 0.0776 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0476 - val_loss: 0.1347 - val_root_mean_squared_error: 0.1346 - val_mean_squared_error: 0.0182 - val_mean_absolute_error: 0.0845
# Epoch 90/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0775 - root_mean_squared_error: 0.0775 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0476 - val_loss: 0.1333 - val_root_mean_squared_error: 0.1331 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.0835
# Epoch 91/1000
# 18389/18389 [==============================] - 6s 314us/sample - loss: 0.0781 - root_mean_squared_error: 0.0781 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0479 - val_loss: 0.1322 - val_root_mean_squared_error: 0.1322 - val_mean_squared_error: 0.0176 - val_mean_absolute_error: 0.0814
# Epoch 92/1000
# 18389/18389 [==============================] - 6s 311us/sample - loss: 0.0779 - root_mean_squared_error: 0.0779 - mean_squared_error: 0.0063 - mean_absolute_error: 0.0478 - val_loss: 0.1322 - val_root_mean_squared_error: 0.1324 - val_mean_squared_error: 0.0176 - val_mean_absolute_error: 0.0818
# Epoch 93/1000
# 18389/18389 [==============================] - 6s 317us/sample - loss: 0.0768 - root_mean_squared_error: 0.0768 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0470 - val_loss: 0.1320 - val_root_mean_squared_error: 0.1318 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.0814
# Epoch 94/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.0762 - root_mean_squared_error: 0.0762 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0468 - val_loss: 0.1321 - val_root_mean_squared_error: 0.1320 - val_mean_squared_error: 0.0176 - val_mean_absolute_error: 0.0818
# Epoch 95/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0749 - root_mean_squared_error: 0.0749 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0460 - val_loss: 0.1350 - val_root_mean_squared_error: 0.1352 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.0833
# Epoch 96/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0749 - root_mean_squared_error: 0.0749 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0459 - val_loss: 0.1362 - val_root_mean_squared_error: 0.1362 - val_mean_squared_error: 0.0186 - val_mean_absolute_error: 0.0837
# Epoch 97/1000
# 18389/18389 [==============================] - 6s 311us/sample - loss: 0.0743 - root_mean_squared_error: 0.0743 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0455 - val_loss: 0.1351 - val_root_mean_squared_error: 0.1354 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.0827
# Epoch 98/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.0743 - root_mean_squared_error: 0.0743 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0457 - val_loss: 0.1327 - val_root_mean_squared_error: 0.1330 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.0807
# Epoch 99/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.0744 - root_mean_squared_error: 0.0744 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0457 - val_loss: 0.1321 - val_root_mean_squared_error: 0.1319 - val_mean_squared_error: 0.0176 - val_mean_absolute_error: 0.0792
# Epoch 100/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0733 - root_mean_squared_error: 0.0733 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0448 - val_loss: 0.1316 - val_root_mean_squared_error: 0.1316 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.0788
# Epoch 101/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.0737 - root_mean_squared_error: 0.0737 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0452 - val_loss: 0.1309 - val_root_mean_squared_error: 0.1313 - val_mean_squared_error: 0.0173 - val_mean_absolute_error: 0.0792
# Epoch 102/1000
# 18389/18389 [==============================] - 6s 316us/sample - loss: 0.0728 - root_mean_squared_error: 0.0728 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0446 - val_loss: 0.1329 - val_root_mean_squared_error: 0.1331 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.0796
# Epoch 103/1000
# 18389/18389 [==============================] - 6s 311us/sample - loss: 0.0724 - root_mean_squared_error: 0.0724 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0442 - val_loss: 0.1294 - val_root_mean_squared_error: 0.1297 - val_mean_squared_error: 0.0169 - val_mean_absolute_error: 0.0777
# Epoch 104/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.0726 - root_mean_squared_error: 0.0726 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0442 - val_loss: 0.1302 - val_root_mean_squared_error: 0.1302 - val_mean_squared_error: 0.0171 - val_mean_absolute_error: 0.0778
# Epoch 105/1000
# 18389/18389 [==============================] - 6s 315us/sample - loss: 0.0717 - root_mean_squared_error: 0.0717 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0436 - val_loss: 0.1337 - val_root_mean_squared_error: 0.1335 - val_mean_squared_error: 0.0180 - val_mean_absolute_error: 0.0784
# Epoch 106/1000
# 18389/18389 [==============================] - 6s 313us/sample - loss: 0.0718 - root_mean_squared_error: 0.0718 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0439 - val_loss: 0.1329 - val_root_mean_squared_error: 0.1325 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.0779
# Epoch 107/1000
# 18389/18389 [==============================] - 6s 321us/sample - loss: 0.0716 - root_mean_squared_error: 0.0716 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0438 - val_loss: 0.1334 - val_root_mean_squared_error: 0.1335 - val_mean_squared_error: 0.0180 - val_mean_absolute_error: 0.0777
# Epoch 108/1000
# 18389/18389 [==============================] - 6s 325us/sample - loss: 0.0712 - root_mean_squared_error: 0.0712 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0434 - val_loss: 0.1332 - val_root_mean_squared_error: 0.1333 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.0765
# Epoch 109/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0713 - root_mean_squared_error: 0.0713 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0434 - val_loss: 0.1343 - val_root_mean_squared_error: 0.1343 - val_mean_squared_error: 0.0182 - val_mean_absolute_error: 0.0771
# Epoch 110/1000
# 18389/18389 [==============================] - 6s 323us/sample - loss: 0.0701 - root_mean_squared_error: 0.0701 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0426 - val_loss: 0.1350 - val_root_mean_squared_error: 0.1348 - val_mean_squared_error: 0.0184 - val_mean_absolute_error: 0.0763
# Epoch 111/1000
# 18389/18389 [==============================] - 6s 322us/sample - loss: 0.0713 - root_mean_squared_error: 0.0713 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0434 - val_loss: 0.1341 - val_root_mean_squared_error: 0.1338 - val_mean_squared_error: 0.0181 - val_mean_absolute_error: 0.0764
# Epoch 112/1000
# 18389/18389 [==============================] - 6s 323us/sample - loss: 0.0705 - root_mean_squared_error: 0.0705 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0432 - val_loss: 0.1343 - val_root_mean_squared_error: 0.1342 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.0767
# Epoch 113/1000
# 18389/18389 [==============================] - 6s 327us/sample - loss: 0.0702 - root_mean_squared_error: 0.0702 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0426 - val_loss: 0.1348 - val_root_mean_squared_error: 0.1348 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.0756
# Epoch 114/1000
# 18389/18389 [==============================] - 6s 326us/sample - loss: 0.0722 - root_mean_squared_error: 0.0722 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0436 - val_loss: 0.1342 - val_root_mean_squared_error: 0.1344 - val_mean_squared_error: 0.0181 - val_mean_absolute_error: 0.0760
# Epoch 115/1000
# 18389/18389 [==============================] - 6s 328us/sample - loss: 0.0709 - root_mean_squared_error: 0.0709 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0430 - val_loss: 0.1319 - val_root_mean_squared_error: 0.1320 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.0751
# Epoch 116/1000
# 18389/18389 [==============================] - 6s 320us/sample - loss: 0.0703 - root_mean_squared_error: 0.0703 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0426 - val_loss: 0.1323 - val_root_mean_squared_error: 0.1322 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.0735
# Epoch 117/1000
# 18389/18389 [==============================] - 6s 321us/sample - loss: 0.0692 - root_mean_squared_error: 0.0692 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0419 - val_loss: 0.1350 - val_root_mean_squared_error: 0.1351 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.0754
# Epoch 118/1000
# 18389/18389 [==============================] - 6s 327us/sample - loss: 0.0679 - root_mean_squared_error: 0.0679 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0411 - val_loss: 0.1313 - val_root_mean_squared_error: 0.1313 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.0723
# Epoch 119/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0676 - root_mean_squared_error: 0.0676 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0409 - val_loss: 0.1320 - val_root_mean_squared_error: 0.1320 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.0737
# Epoch 120/1000
# 18389/18389 [==============================] - 6s 328us/sample - loss: 0.0674 - root_mean_squared_error: 0.0674 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0408 - val_loss: 0.1325 - val_root_mean_squared_error: 0.1327 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.0741
# Epoch 121/1000
# 18389/18389 [==============================] - 6s 325us/sample - loss: 0.0677 - root_mean_squared_error: 0.0677 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0410 - val_loss: 0.1323 - val_root_mean_squared_error: 0.1326 - val_mean_squared_error: 0.0176 - val_mean_absolute_error: 0.0743
# Epoch 122/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0663 - root_mean_squared_error: 0.0663 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0402 - val_loss: 0.1332 - val_root_mean_squared_error: 0.1332 - val_mean_squared_error: 0.0179 - val_mean_absolute_error: 0.0746
# Epoch 123/1000
# 18389/18389 [==============================] - 6s 328us/sample - loss: 0.0675 - root_mean_squared_error: 0.0675 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0408 - val_loss: 0.1343 - val_root_mean_squared_error: 0.1341 - val_mean_squared_error: 0.0181 - val_mean_absolute_error: 0.0754
# Epoch 124/1000
# 18389/18389 [==============================] - 6s 329us/sample - loss: 0.0675 - root_mean_squared_error: 0.0675 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0410 - val_loss: 0.1310 - val_root_mean_squared_error: 0.1309 - val_mean_squared_error: 0.0173 - val_mean_absolute_error: 0.0729
# Epoch 125/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0663 - root_mean_squared_error: 0.0663 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0401 - val_loss: 0.1315 - val_root_mean_squared_error: 0.1318 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.0744
# Epoch 126/1000
# 18389/18389 [==============================] - 6s 328us/sample - loss: 0.0661 - root_mean_squared_error: 0.0661 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0401 - val_loss: 0.1348 - val_root_mean_squared_error: 0.1346 - val_mean_squared_error: 0.0183 - val_mean_absolute_error: 0.0746
# Epoch 127/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0655 - root_mean_squared_error: 0.0655 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0398 - val_loss: 0.1338 - val_root_mean_squared_error: 0.1338 - val_mean_squared_error: 0.0180 - val_mean_absolute_error: 0.0753
# Epoch 128/1000
# 18389/18389 [==============================] - 6s 327us/sample - loss: 0.0658 - root_mean_squared_error: 0.0658 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0399 - val_loss: 0.1274 - val_root_mean_squared_error: 0.1274 - val_mean_squared_error: 0.0163 - val_mean_absolute_error: 0.0724
# Epoch 129/1000
# 18389/18389 [==============================] - 6s 327us/sample - loss: 0.0658 - root_mean_squared_error: 0.0658 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0400 - val_loss: 0.1330 - val_root_mean_squared_error: 0.1332 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.0743
# Epoch 130/1000
# 18389/18389 [==============================] - 6s 326us/sample - loss: 0.0656 - root_mean_squared_error: 0.0656 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0398 - val_loss: 0.1266 - val_root_mean_squared_error: 0.1262 - val_mean_squared_error: 0.0161 - val_mean_absolute_error: 0.0729
# Epoch 131/1000
# 18389/18389 [==============================] - 6s 326us/sample - loss: 0.0654 - root_mean_squared_error: 0.0654 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0398 - val_loss: 0.1319 - val_root_mean_squared_error: 0.1319 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.0738
# Epoch 132/1000
# 18389/18389 [==============================] - 6s 329us/sample - loss: 0.0643 - root_mean_squared_error: 0.0643 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0390 - val_loss: 0.1327 - val_root_mean_squared_error: 0.1324 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.0741
# Epoch 133/1000
# 18389/18389 [==============================] - 6s 321us/sample - loss: 0.0648 - root_mean_squared_error: 0.0648 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0394 - val_loss: 0.1312 - val_root_mean_squared_error: 0.1313 - val_mean_squared_error: 0.0173 - val_mean_absolute_error: 0.0736
# Epoch 134/1000
# 18389/18389 [==============================] - 6s 322us/sample - loss: 0.0643 - root_mean_squared_error: 0.0643 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0389 - val_loss: 0.1271 - val_root_mean_squared_error: 0.1271 - val_mean_squared_error: 0.0162 - val_mean_absolute_error: 0.0723
# Epoch 135/1000
# 18389/18389 [==============================] - 6s 327us/sample - loss: 0.0636 - root_mean_squared_error: 0.0636 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0386 - val_loss: 0.1324 - val_root_mean_squared_error: 0.1322 - val_mean_squared_error: 0.0176 - val_mean_absolute_error: 0.0746
# Epoch 136/1000
# 18389/18389 [==============================] - 6s 326us/sample - loss: 0.0631 - root_mean_squared_error: 0.0631 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0384 - val_loss: 0.1306 - val_root_mean_squared_error: 0.1309 - val_mean_squared_error: 0.0172 - val_mean_absolute_error: 0.0736
# Epoch 137/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0639 - root_mean_squared_error: 0.0639 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0387 - val_loss: 0.1316 - val_root_mean_squared_error: 0.1316 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.0732
# Epoch 138/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0634 - root_mean_squared_error: 0.0634 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0384 - val_loss: 0.1304 - val_root_mean_squared_error: 0.1300 - val_mean_squared_error: 0.0171 - val_mean_absolute_error: 0.0731
# Epoch 139/1000
# 18389/18389 [==============================] - 6s 326us/sample - loss: 0.0642 - root_mean_squared_error: 0.0642 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0389 - val_loss: 0.1329 - val_root_mean_squared_error: 0.1328 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.0742
# Epoch 140/1000
# 18389/18389 [==============================] - 6s 323us/sample - loss: 0.0630 - root_mean_squared_error: 0.0630 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0381 - val_loss: 0.1316 - val_root_mean_squared_error: 0.1314 - val_mean_squared_error: 0.0175 - val_mean_absolute_error: 0.0741
# Epoch 141/1000
# 18389/18389 [==============================] - 6s 320us/sample - loss: 0.0639 - root_mean_squared_error: 0.0639 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0387 - val_loss: 0.1292 - val_root_mean_squared_error: 0.1289 - val_mean_squared_error: 0.0168 - val_mean_absolute_error: 0.0730
# Epoch 142/1000
# 18389/18389 [==============================] - 6s 325us/sample - loss: 0.0627 - root_mean_squared_error: 0.0627 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0381 - val_loss: 0.1312 - val_root_mean_squared_error: 0.1309 - val_mean_squared_error: 0.0173 - val_mean_absolute_error: 0.0747
# Epoch 143/1000
# 18389/18389 [==============================] - 6s 328us/sample - loss: 0.0627 - root_mean_squared_error: 0.0628 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0379 - val_loss: 0.1287 - val_root_mean_squared_error: 0.1285 - val_mean_squared_error: 0.0167 - val_mean_absolute_error: 0.0728
# Epoch 144/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0618 - root_mean_squared_error: 0.0618 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0375 - val_loss: 0.1306 - val_root_mean_squared_error: 0.1304 - val_mean_squared_error: 0.0172 - val_mean_absolute_error: 0.0733
# Epoch 145/1000
# 18389/18389 [==============================] - 6s 323us/sample - loss: 0.0616 - root_mean_squared_error: 0.0616 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0374 - val_loss: 0.1307 - val_root_mean_squared_error: 0.1307 - val_mean_squared_error: 0.0172 - val_mean_absolute_error: 0.0737
# Epoch 146/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0623 - root_mean_squared_error: 0.0623 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0378 - val_loss: 0.1314 - val_root_mean_squared_error: 0.1314 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.0735
# Epoch 147/1000
# 18389/18389 [==============================] - 6s 327us/sample - loss: 0.0630 - root_mean_squared_error: 0.0630 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0383 - val_loss: 0.1302 - val_root_mean_squared_error: 0.1301 - val_mean_squared_error: 0.0171 - val_mean_absolute_error: 0.0729
# Epoch 148/1000
# 18389/18389 [==============================] - 6s 326us/sample - loss: 0.0622 - root_mean_squared_error: 0.0622 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0377 - val_loss: 0.1295 - val_root_mean_squared_error: 0.1295 - val_mean_squared_error: 0.0169 - val_mean_absolute_error: 0.0718
# Epoch 149/1000
# 18389/18389 [==============================] - 6s 324us/sample - loss: 0.0618 - root_mean_squared_error: 0.0618 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0375 - val_loss: 0.1313 - val_root_mean_squared_error: 0.1308 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.0726
# Epoch 150/1000
# 18389/18389 [==============================] - 6s 327us/sample - loss: 0.0612 - root_mean_squared_error: 0.0612 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0372 - val_loss: 0.1291 - val_root_mean_squared_error: 0.1294 - val_mean_squared_error: 0.0168 - val_mean_absolute_error: 0.0716
# Epoch 151/1000
# 18389/18389 [==============================] - 6s 329us/sample - loss: 0.0612 - root_mean_squared_error: 0.0612 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0372 - val_loss: 0.1302 - val_root_mean_squared_error: 0.1303 - val_mean_squared_error: 0.0170 - val_mean_absolute_error: 0.0717
# Epoch 152/1000
# 18389/18389 [==============================] - 6s 326us/sample - loss: 0.0614 - root_mean_squared_error: 0.0614 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0374 - val_loss: 0.1303 - val_root_mean_squared_error: 0.1301 - val_mean_squared_error: 0.0171 - val_mean_absolute_error: 0.0715
# Epoch 153/1000
# 18389/18389 [==============================] - 6s 327us/sample - loss: 0.0606 - root_mean_squared_error: 0.0606 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0368 - val_loss: 0.1309 - val_root_mean_squared_error: 0.1307 - val_mean_squared_error: 0.0172 - val_mean_absolute_error: 0.0718
# Epoch 154/1000
# ...
# Epoch 547/1000
# 18389/18389 [==============================] - 6s 304us/sample - loss: 0.0404 - root_mean_squared_error: 0.0404 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.1243 - val_root_mean_squared_error: 0.1243 - val_mean_squared_error: 0.0156 - val_mean_absolute_error: 0.0702
# Epoch 548/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0399 - root_mean_squared_error: 0.0399 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0242 - val_loss: 0.1243 - val_root_mean_squared_error: 0.1242 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.06806 - root_mean_square
# Epoch 549/1000
# 18389/18389 [==============================] - 6s 306us/sample - loss: 0.0401 - root_mean_squared_error: 0.0401 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0244 - val_loss: 0.1242 - val_root_mean_squared_error: 0.1241 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0684
# Epoch 550/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0399 - root_mean_squared_error: 0.0399 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0243 - val_loss: 0.1235 - val_root_mean_squared_error: 0.1235 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0669
# Epoch 551/1000
# 18389/18389 [==============================] - 6s 308us/sample - loss: 0.0396 - root_mean_squared_error: 0.0396 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.1233 - val_root_mean_squared_error: 0.1233 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0667
# Epoch 552/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0397 - root_mean_squared_error: 0.0397 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0241 - val_loss: 0.1238 - val_root_mean_squared_error: 0.1238 - val_mean_squared_error: 0.0154 - val_mean_absolute_error: 0.0659
# Epoch 553/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0393 - root_mean_squared_error: 0.0393 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0238 - val_loss: 0.1231 - val_root_mean_squared_error: 0.1229 - val_mean_squared_error: 0.0152 - val_mean_absolute_error: 0.0658
# Epoch 554/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0405 - root_mean_squared_error: 0.0405 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.1223 - val_root_mean_squared_error: 0.1223 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0656
# Epoch 555/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0407 - root_mean_squared_error: 0.0407 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.1235 - val_root_mean_squared_error: 0.1236 - val_mean_squared_error: 0.0154 - val_mean_absolute_error: 0.0670
# Epoch 556/1000
# 18389/18389 [==============================] - 6s 310us/sample - loss: 0.0405 - root_mean_squared_error: 0.0405 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.1233 - val_root_mean_squared_error: 0.1232 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0673
# Epoch 557/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0398 - root_mean_squared_error: 0.0398 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0241 - val_loss: 0.1239 - val_root_mean_squared_error: 0.1237 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0681
# Epoch 558/1000
# 18389/18389 [==============================] - 6s 306us/sample - loss: 0.0396 - root_mean_squared_error: 0.0396 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.1250 - val_root_mean_squared_error: 0.1252 - val_mean_squared_error: 0.0157 - val_mean_absolute_error: 0.0691
# Epoch 559/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0398 - root_mean_squared_error: 0.0398 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0242 - val_loss: 0.1253 - val_root_mean_squared_error: 0.1252 - val_mean_squared_error: 0.0158 - val_mean_absolute_error: 0.0703
# Epoch 560/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0394 - root_mean_squared_error: 0.0394 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.1243 - val_root_mean_squared_error: 0.1244 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0703
# Epoch 561/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0399 - root_mean_squared_error: 0.0399 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0242 - val_loss: 0.1229 - val_root_mean_squared_error: 0.1229 - val_mean_squared_error: 0.0152 - val_mean_absolute_error: 0.0688
# Epoch 562/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0404 - root_mean_squared_error: 0.0404 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0244 - val_loss: 0.1222 - val_root_mean_squared_error: 0.1223 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0679
# Epoch 563/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0403 - root_mean_squared_error: 0.0403 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0244 - val_loss: 0.1236 - val_root_mean_squared_error: 0.1234 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0684
# Epoch 564/1000
# 18389/18389 [==============================] - 6s 308us/sample - loss: 0.0404 - root_mean_squared_error: 0.0404 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.1240 - val_root_mean_squared_error: 0.1239 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0679
# Epoch 565/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0408 - root_mean_squared_error: 0.0408 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.1230 - val_root_mean_squared_error: 0.1230 - val_mean_squared_error: 0.0152 - val_mean_absolute_error: 0.0673
# Epoch 566/1000
# 18389/18389 [==============================] - 6s 308us/sample - loss: 0.0407 - root_mean_squared_error: 0.0407 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.1228 - val_root_mean_squared_error: 0.1227 - val_mean_squared_error: 0.0152 - val_mean_absolute_error: 0.0677
# Epoch 567/1000
# 18389/18389 [==============================] - 6s 308us/sample - loss: 0.0404 - root_mean_squared_error: 0.0404 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0244 - val_loss: 0.1231 - val_root_mean_squared_error: 0.1231 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0675
# Epoch 568/1000
# 18389/18389 [==============================] - 6s 306us/sample - loss: 0.0400 - root_mean_squared_error: 0.0400 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0243 - val_loss: 0.1223 - val_root_mean_squared_error: 0.1220 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0680
# Epoch 569/1000
# 18389/18389 [==============================] - 6s 306us/sample - loss: 0.0395 - root_mean_squared_error: 0.0395 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.1226 - val_root_mean_squared_error: 0.1225 - val_mean_squared_error: 0.0151 - val_mean_absolute_error: 0.0686
# Epoch 570/1000
# 18389/18389 [==============================] - 6s 308us/sample - loss: 0.0393 - root_mean_squared_error: 0.0393 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 0.1233 - val_root_mean_squared_error: 0.1233 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0684
# Epoch 571/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0395 - root_mean_squared_error: 0.0395 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.1254 - val_root_mean_squared_error: 0.1251 - val_mean_squared_error: 0.0158 - val_mean_absolute_error: 0.0699
# Epoch 572/1000
# 18389/18389 [==============================] - 6s 312us/sample - loss: 0.0393 - root_mean_squared_error: 0.0393 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 0.1238 - val_root_mean_squared_error: 0.1236 - val_mean_squared_error: 0.0154 - val_mean_absolute_error: 0.0688
# Epoch 573/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0393 - root_mean_squared_error: 0.0393 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0238 - val_loss: 0.1227 - val_root_mean_squared_error: 0.1226 - val_mean_squared_error: 0.0151 - val_mean_absolute_error: 0.0673
# Epoch 574/1000
# 18389/18389 [==============================] - 6s 310us/sample - loss: 0.0391 - root_mean_squared_error: 0.0391 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0237 - val_loss: 0.1231 - val_root_mean_squared_error: 0.1230 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0677
# Epoch 575/1000
# 18389/18389 [==============================] - 6s 308us/sample - loss: 0.0388 - root_mean_squared_error: 0.0388 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0235 - val_loss: 0.1225 - val_root_mean_squared_error: 0.1225 - val_mean_squared_error: 0.0151 - val_mean_absolute_error: 0.0669
# Epoch 576/1000
# 18389/18389 [==============================] - 6s 309us/sample - loss: 0.0391 - root_mean_squared_error: 0.0391 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0238 - val_loss: 0.1238 - val_root_mean_squared_error: 0.1240 - val_mean_squared_error: 0.0154 - val_mean_absolute_error: 0.0667
# Epoch 577/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0392 - root_mean_squared_error: 0.0392 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0237 - val_loss: 0.1240 - val_root_mean_squared_error: 0.1238 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0667
# Epoch 578/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0390 - root_mean_squared_error: 0.0390 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0237 - val_loss: 0.1233 - val_root_mean_squared_error: 0.1233 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0666
# Epoch 579/1000
# 18389/18389 [==============================] - 6s 305us/sample - loss: 0.0389 - root_mean_squared_error: 0.0389 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0236 - val_loss: 0.1234 - val_root_mean_squared_error: 0.1234 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0667
# Epoch 580/1000
# 18389/18389 [==============================] - 6s 306us/sample - loss: 0.0392 - root_mean_squared_error: 0.0392 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0238 - val_loss: 0.1221 - val_root_mean_squared_error: 0.1220 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0666
# Epoch 581/1000
# 18389/18389 [==============================] - 6s 306us/sample - loss: 0.0392 - root_mean_squared_error: 0.0392 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0238 - val_loss: 0.1224 - val_root_mean_squared_error: 0.1223 - val_mean_squared_error: 0.0151 - val_mean_absolute_error: 0.0669
# Epoch 582/1000
# 18389/18389 [==============================] - 6s 306us/sample - loss: 0.0390 - root_mean_squared_error: 0.0390 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0236 - val_loss: 0.1220 - val_root_mean_squared_error: 0.1221 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0680
# Epoch 583/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0392 - root_mean_squared_error: 0.0392 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0238 - val_loss: 0.1223 - val_root_mean_squared_error: 0.1222 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0673
# Epoch 584/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0394 - root_mean_squared_error: 0.0394 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 0.1226 - val_root_mean_squared_error: 0.1226 - val_mean_squared_error: 0.0151 - val_mean_absolute_error: 0.0675
# Epoch 585/1000
# 18389/18389 [==============================] - 6s 308us/sample - loss: 0.0393 - root_mean_squared_error: 0.0394 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 0.1224 - val_root_mean_squared_error: 0.1224 - val_mean_squared_error: 0.0151 - val_mean_absolute_error: 0.0678
# Epoch 586/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0390 - root_mean_squared_error: 0.0390 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0237 - val_loss: 0.1219 - val_root_mean_squared_error: 0.1216 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0671
# Epoch 587/1000
# 18389/18389 [==============================] - 6s 306us/sample - loss: 0.0387 - root_mean_squared_error: 0.0387 - mean_squared_error: 0.0015 - mean_absolute_error: 0.0234 - val_loss: 0.1219 - val_root_mean_squared_error: 0.1221 - val_mean_squared_error: 0.0149 - val_mean_absolute_error: 0.0674
# Epoch 588/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0389 - root_mean_squared_error: 0.0389 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0236 - val_loss: 0.1232 - val_root_mean_squared_error: 0.1234 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0674
# Epoch 589/1000
# 18389/18389 [==============================] - 6s 305us/sample - loss: 0.0395 - root_mean_squared_error: 0.0395 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 0.1231 - val_root_mean_squared_error: 0.1231 - val_mean_squared_error: 0.0152 - val_mean_absolute_error: 0.0668
# Epoch 590/1000
# 18389/18389 [==============================] - 6s 307us/sample - loss: 0.0396 - root_mean_squared_error: 0.0396 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.1237 - val_root_mean_squared_error: 0.1235 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0667
# Epoch 591/1000
# 18389/18389 [==============================] - 6s 306us/sample - loss: 0.0397 - root_mean_squared_error: 0.0397 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0241 - val_loss: 0.1219 - val_root_mean_squared_error: 0.1221 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0649
# Epoch 592/1000
# 18389/18389 [==============================] - 6s 318us/sample - loss: 0.0401 - root_mean_squared_error: 0.0401 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0243 - val_loss: 0.1232 - val_root_mean_squared_error: 0.1229 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0667
# Epoch 593/1000
# 18389/18389 [==============================] - 6s 319us/sample - loss: 0.0399 - root_mean_squared_error: 0.0399 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0241 - val_loss: 0.1233 - val_root_mean_squared_error: 0.1236 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0663
# Epoch 594/1000
# 18389/18389 [==============================] - 6s 318us/sample - loss: 0.0396 - root_mean_squared_error: 0.0396 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.1244 - val_root_mean_squared_error: 0.1242 - val_mean_squared_error: 0.0156 - val_mean_absolute_error: 0.0672
# Epoch 595/1000
# 18389/18389 [==============================] - 6s 322us/sample - loss: 0.0394 - root_mean_squared_error: 0.0394 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 0.1228 - val_root_mean_squared_error: 0.1226 - val_mean_squared_error: 0.0152 - val_mean_absolute_error: 0.0670
# Epoch 596/1000
# 18389/18389 [==============================] - 6s 323us/sample - loss: 0.0392 - root_mean_squared_error: 0.0392 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0237 - val_loss: 0.1210 - val_root_mean_squared_error: 0.1210 - val_mean_squared_error: 0.0147 - val_mean_absolute_error: 0.0670
# Epoch 597/1000
# 18389/18389 [==============================] - 6s 321us/sample - loss: 0.0393 - root_mean_squared_error: 0.0393 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 0.1223 - val_root_mean_squared_error: 0.1223 - val_mean_squared_error: 0.0151 - val_mean_absolute_error: 0.0666
# Wall time: 57min 37s

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8)) 
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('PV_Tl24h_TrainingandValidation Loss.png')
plt.show()

#print(get_flops(model))

# %%
trainPredict = model.predict(trX, batch_size=batch_size)
validPredict = model.predict(vaX, batch_size=batch_size)
testPredict = model.predict(teX, batch_size=batch_size)

# %%
tePredict = testPredict.reshape([-1])
testY = teY.reshape([-1])

np.savetxt('PV_Tl24h_testPredict.txt', tePredict)
 
print('Error Test Score > RMSE == ', np.sqrt(np.mean(np.square(testY-tePredict))), ' MAE == ', mean_absolute_error(testY, tePredict))
# Out:
# Error Test Score > RMSE ==  0.11871417849391848  MAE ==  0.06423763616888337

# %%
plt.figure(figsize=(16,8)) 
plt.plot(tePredict[0:300])
plt.plot(testY[0:300])
plt.ylabel('Value')
plt.xlabel('time(h)')
plt.legend(['tePredict', 'testY'], loc='upper left')
plt.show()

# %%
e_tr = trainPredict - trY
e_va = validPredict - vaY
errors = np.vstack([e_tr,e_va])
prediction = np.vstack([trainPredict,validPredict])
print(errors.shape)
print(prediction.shape)
# Out:
# (21447, 12)
# (21447, 12)

# %%
dataset = np.hstack([pv_dat, weather_dat])
index = ['Measured PV', 'Temperature C', 'Rainfall', 'Wind speed', 'Wind direction', 'Humidity', 'Air pressure', 'Dew point C', 'Sunshine', 'Solar radiation', 'Snowfall', 'Cloud cover', 'Surface temp C']

df = pd.DataFrame(dataset, columns=index)
df.head()
df = df.fillna(0)
min_max_scaler = preprocessing.MinMaxScaler()
norm_df = pd.DataFrame(min_max_scaler.fit_transform(df), 
                             columns=df.columns, 
                             index=df.index)
norm_df2 = norm_df.iloc[:21447, :].copy()
norm_df2.head()
# Out:
#    Measured PV  Temperature C  Rainfall  Wind speed  Wind direction  Humidity  \
# 0          0.0       0.354298       0.0    0.023256        0.000000      0.89
# 1          0.0       0.339623       0.0    0.104651        0.444444      0.93
# 2          0.0       0.320755       0.0    0.046512        0.388889      0.93
# 3          0.0       0.303983       0.0    0.087209        0.444444      0.94
# 4          0.0       0.287212       0.0    0.104651        0.444444      0.95
#
#    Air pressure  Dew point C  Sunshine  Solar radiation  Snowfall  \
# 0      0.189696     0.444681       0.0              0.0       0.0
# 1      0.189696     0.442553       0.0              0.0       0.0
# 2      0.177986     0.423404       0.0              0.0       0.0
# 3      0.170960     0.410638       0.0              0.0       0.0
# 4      0.161593     0.395745       0.0              0.0       0.0
#
#    Cloud cover  Surface temp C
# 0          0.6        0.141834
# 1          0.0        0.117479
# 2          0.0        0.103152
# 3          0.0        0.095989
# 4          0.0        0.088825

# %%
norm_df2 = norm_df2.iloc[:,[0, 1, 4, 5, 6, 8, 9, 11, 12]]
norm_df2.head()
# Out:
#    Measured PV  Temperature C  Wind direction  Humidity  Air pressure  \
# 0          0.0       0.354298        0.000000      0.89      0.189696
# 1          0.0       0.339623        0.444444      0.93      0.189696
# 2          0.0       0.320755        0.388889      0.93      0.177986
# 3          0.0       0.303983        0.444444      0.94      0.170960
# 4          0.0       0.287212        0.444444      0.95      0.161593
#
#    Sunshine  Solar radiation  Cloud cover  Surface temp C
# 0       0.0              0.0          0.6        0.141834
# 1       0.0              0.0          0.0        0.117479
# 2       0.0              0.0          0.0        0.103152
# 3       0.0              0.0          0.0        0.095989
# 4       0.0              0.0          0.0        0.088825

# %%
Prindex = ['Prediction1', 'Prediction2','Prediction3','Prediction4','Prediction5','Prediction6','Prediction7','Prediction8','Prediction9','Prediction10','Prediction11','Prediction12']
Erindex = ['Error1', 'Error2','Error3','Error4','Error5','Error6','Error7','Error8','Error9','Error10','Error11','Error12']

pr_df = pd.DataFrame(prediction, columns=Prindex)
pr_df.head()
# Out:
#    Prediction1  Prediction2  Prediction3  Prediction4  Prediction5  \
# 0     0.017401     0.022884     0.069371     0.215551     0.425605
# 1     0.005587     0.079787     0.258593     0.478822     0.612173
# 2     0.055362     0.194887     0.389718     0.556385     0.605449
# 3     0.195578     0.410183     0.586095     0.646613     0.591130
# 4     0.507296     0.642254     0.666855     0.598764     0.461605
#
#    Prediction6  Prediction7  Prediction8  Prediction9  Prediction10  \
# 0     0.578426     0.609977     0.550544     0.459153      0.315669
# 1     0.642315     0.594937     0.473099     0.299911      0.133585
# 2     0.563369     0.453648     0.280050     0.095852      0.003757
# 3     0.467601     0.308081     0.145617     0.040337      0.010667
# 4     0.287963     0.124183     0.030220     0.006124      0.009996
#
#    Prediction11  Prediction12
# 0      0.137183     -0.011028
# 1      0.027361     -0.004522
# 2     -0.011705     -0.003421
# 3      0.002433     -0.000128
# 4      0.004863     -0.005445

# %%
er_df = pd.DataFrame(errors, columns=Erindex)
er_df.head()
# Out:
#      Error1    Error2    Error3    Error4    Error5    Error6    Error7  \
# 0  0.017401  0.022884  0.041464  0.058187 -0.075945 -0.013823 -0.062891
# 1  0.005587  0.051881  0.101229 -0.022728  0.019924 -0.030553  0.006565
# 2  0.027455  0.037522 -0.111832 -0.035863 -0.067419 -0.025003 -0.059530
# 3  0.038213 -0.091367 -0.006153 -0.026255  0.002758 -0.045577 -0.056260
# 4  0.005746  0.050006 -0.006013  0.010392 -0.051574 -0.076378 -0.003724
#
#      Error8    Error9   Error10   Error11   Error12
# 0 -0.037828 -0.054025 -0.048672  0.009276 -0.017229
# 1 -0.040079 -0.064430  0.005678  0.021159 -0.004522
# 2 -0.084291 -0.032055 -0.002445 -0.011705 -0.003421
# 3  0.017710  0.034136  0.010667  0.002433 -0.000128
# 4  0.024018  0.006124  0.009996  0.004863 -0.005445

# %%
norm_df2 = pd.concat([norm_df2, pr_df, er_df],axis=1)
norm_df2.head()
# Out:
#    Measured PV  Temperature C  Wind direction  Humidity  Air pressure  \
# 0          0.0       0.354298        0.000000      0.89      0.189696
# 1          0.0       0.339623        0.444444      0.93      0.189696
# 2          0.0       0.320755        0.388889      0.93      0.177986
# 3          0.0       0.303983        0.444444      0.94      0.170960
# 4          0.0       0.287212        0.444444      0.95      0.161593
#
#    Sunshine  Solar radiation  Cloud cover  Surface temp C  Prediction1  ...  \
# 0       0.0              0.0          0.6        0.141834     0.017401  ...
# 1       0.0              0.0          0.0        0.117479     0.005587  ...
# 2       0.0              0.0          0.0        0.103152     0.055362  ...
# 3       0.0              0.0          0.0        0.095989     0.195578  ...
# 4       0.0              0.0          0.0        0.088825     0.507296  ...
#
#      Error3    Error4    Error5    Error6    Error7    Error8    Error9  \
# 0  0.041464  0.058187 -0.075945 -0.013823 -0.062891 -0.037828 -0.054025
# 1  0.101229 -0.022728  0.019924 -0.030553  0.006565 -0.040079 -0.064430
# 2 -0.111832 -0.035863 -0.067419 -0.025003 -0.059530 -0.084291 -0.032055
# 3 -0.006153 -0.026255  0.002758 -0.045577 -0.056260  0.017710  0.034136
# 4 -0.006013  0.010392 -0.051574 -0.076378 -0.003724  0.024018  0.006124
#
#     Error10   Error11   Error12
# 0 -0.048672  0.009276 -0.017229
# 1  0.005678  0.021159 -0.004522
# 2 -0.002445 -0.011705 -0.003421
# 3  0.010667  0.002433 -0.000128
# 4  0.009996  0.004863 -0.005445
#
# [5 rows x 33 columns]

# %%
import seaborn as sns
from keijzer import *

fig = create_corr_matrix(norm_df2, 'Correlation Matrix of all components in dataset', True, size=(25,25))
fig.savefig('correlation_matrix.png')
# Out:
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Saving heatmap

# %%
norm_df2 = np.array(norm_df2)
print(norm_df2.shape)
timesteps = 30
output_timesteps = 1
Xe, Ye = create_dataset(norm_df2, timesteps, output_timesteps)
print(Xe.shape)
print(Ye.shape)
# Out:
# (21447, 33)
# (21415, 30, 33)
# (21415, 1, 33)

# %%
trXe = Xe[:19000, :, :]
vaXe = Xe[19000:, :, :]
trYe = Ye[:19000, :, -12:]
vaYe = Ye[19000:, :, -12:]
trYe = trYe.reshape(-1,12)
vaYe = vaYe.reshape(-1,12)
print(trXe.shape)
print(trYe.shape)
print(vaXe.shape)
# Out:
# (19000, 30, 33)
# (19000, 12)
# (2415, 30, 33)

# %%
with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1.2
    beta = 1.178511
    num_features = 33
    hfilters = 128
    hkernel_size1 = 2
    hkernel_size2 = 4
    visible1e = Input(shape=(timesteps, num_features))
    per1 = Permute((2,1))(visible1e)
    den1a = Dense(timesteps, activation='tanh')(per1)
    den1b = Dense(timesteps, activation='sigmoid')(per1)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vece')(den1)
    mul1 = Multiply()([visible1e, per2])
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res01 = Add()([d1, visible1e])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res02 = Add()([d1, res01])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res03 = Add()([d1, res02])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=16)(d1)  
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res04 =Add()([d1, res03])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=16)(res04)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=32)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res05 = Add()([d1, res04])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=32)(res05) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=16)(d1)   
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res06 = Add()([d1, res05])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=16)(res06) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res07 = Add()([d1, res06])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res07)  
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res08 = Add()([d1, res07])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res08)   
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)  
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res09 = Add()([d1, res08])   # (100, 25) (100, 25)
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res09) 
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res10 = Add()([d1, res09])   # 
    
    print('res10 :', res10.shape)  # (None, 24, 11) 
    
    oute = Conv1D(512, 1, padding='same', activation='relu')(res10)   # 256, 11X10=110  
    oute = Dropout(0.2)(oute)   
    
    oute = Conv1D(256, 1, padding='same', activation='relu')(oute) # 512,  110X5=550
    oute = Dropout(0.2)(oute)  
    
    oute = GlobalAveragePooling1D()(oute) # pool_size=2, strides=1
    
    oute = Dense(12)(oute) 
    modele = Model(inputs=[visible1e], outputs=[oute])
    
    print(modele.summary())
    
    modele.compile(loss=root_mean_squared_error, optimizer='adam', metrics=[root_mean_squared_error, 'mse', 'mae', 'mape'])
    early_stopping =EarlyStopping(monitor='val_loss', patience=100)
    batch_size = 100
    epochs = 1000

    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# res10 : (?, 30, 33)
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 30, 33)]     0
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 33, 30)       0           input_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 33, 30)       930         permute_3[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 33, 30)       930         permute_3[0][0]
# __________________________________________________________________________________________________
# multiply_66 (Multiply)          (None, 33, 30)       0           dense_9[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# attention_vece (Permute)        (None, 30, 33)       0           multiply_66[0][0]
# __________________________________________________________________________________________________
# multiply_67 (Multiply)          (None, 30, 33)       0           input_4[0][0]
#                                                                  attention_vece[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 30, 128)      8576        multiply_67[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 30, 128)      0           conv1d_66[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 30, 128)      0           conv1d_66[0][0]
# __________________________________________________________________________________________________
# multiply_68 (Multiply)          (None, 30, 128)      0           activation_120[0][0]
#                                                                  activation_121[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 30, 33)       21153       multiply_68[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 30, 33)       0           conv1d_67[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 30, 33)       0           conv1d_67[0][0]
# __________________________________________________________________________________________________
# multiply_69 (Multiply)          (None, 30, 33)       0           activation_122[0][0]
#                                                                  activation_123[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 30, 33)       0           multiply_69[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 30, 128)      8576        add_30[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 30, 128)      0           conv1d_68[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 30, 128)      0           conv1d_68[0][0]
# __________________________________________________________________________________________________
# multiply_70 (Multiply)          (None, 30, 128)      0           activation_124[0][0]
#                                                                  activation_125[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 30, 33)       21153       multiply_70[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 30, 33)       0           conv1d_69[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 30, 33)       0           conv1d_69[0][0]
# __________________________________________________________________________________________________
# multiply_71 (Multiply)          (None, 30, 33)       0           activation_126[0][0]
#                                                                  activation_127[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 30, 33)       0           multiply_71[0][0]
#                                                                  add_30[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 30, 128)      8576        add_31[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 30, 128)      0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 30, 128)      0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# multiply_72 (Multiply)          (None, 30, 128)      0           activation_128[0][0]
#                                                                  activation_129[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 30, 33)       21153       multiply_72[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 30, 33)       0           conv1d_71[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 30, 33)       0           conv1d_71[0][0]
# __________________________________________________________________________________________________
# multiply_73 (Multiply)          (None, 30, 33)       0           activation_130[0][0]
#                                                                  activation_131[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 30, 33)       0           multiply_73[0][0]
#                                                                  add_31[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 30, 128)      8576        add_32[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 30, 128)      0           conv1d_72[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 30, 128)      0           conv1d_72[0][0]
# __________________________________________________________________________________________________
# multiply_74 (Multiply)          (None, 30, 128)      0           activation_132[0][0]
#                                                                  activation_133[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 30, 33)       21153       multiply_74[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 30, 33)       0           conv1d_73[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 30, 33)       0           conv1d_73[0][0]
# __________________________________________________________________________________________________
# multiply_75 (Multiply)          (None, 30, 33)       0           activation_134[0][0]
#                                                                  activation_135[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 30, 33)       0           multiply_75[0][0]
#                                                                  add_32[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 30, 128)      8576        add_33[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 30, 128)      0           conv1d_74[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 30, 128)      0           conv1d_74[0][0]
# __________________________________________________________________________________________________
# multiply_76 (Multiply)          (None, 30, 128)      0           activation_136[0][0]
#                                                                  activation_137[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 30, 33)       21153       multiply_76[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 30, 33)       0           conv1d_75[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 30, 33)       0           conv1d_75[0][0]
# __________________________________________________________________________________________________
# multiply_77 (Multiply)          (None, 30, 33)       0           activation_138[0][0]
#                                                                  activation_139[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 30, 33)       0           multiply_77[0][0]
#                                                                  add_33[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 30, 128)      8576        add_34[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 30, 128)      0           conv1d_76[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 30, 128)      0           conv1d_76[0][0]
# __________________________________________________________________________________________________
# multiply_78 (Multiply)          (None, 30, 128)      0           activation_140[0][0]
#                                                                  activation_141[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 30, 33)       21153       multiply_78[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 30, 33)       0           conv1d_77[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 30, 33)       0           conv1d_77[0][0]
# __________________________________________________________________________________________________
# multiply_79 (Multiply)          (None, 30, 33)       0           activation_142[0][0]
#                                                                  activation_143[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 30, 33)       0           multiply_79[0][0]
#                                                                  add_34[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 30, 128)      8576        add_35[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 30, 128)      0           conv1d_78[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 30, 128)      0           conv1d_78[0][0]
# __________________________________________________________________________________________________
# multiply_80 (Multiply)          (None, 30, 128)      0           activation_144[0][0]
#                                                                  activation_145[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 30, 33)       21153       multiply_80[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 30, 33)       0           conv1d_79[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 30, 33)       0           conv1d_79[0][0]
# __________________________________________________________________________________________________
# multiply_81 (Multiply)          (None, 30, 33)       0           activation_146[0][0]
#                                                                  activation_147[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 30, 33)       0           multiply_81[0][0]
#                                                                  add_35[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 30, 128)      8576        add_36[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 30, 128)      0           conv1d_80[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 30, 128)      0           conv1d_80[0][0]
# __________________________________________________________________________________________________
# multiply_82 (Multiply)          (None, 30, 128)      0           activation_148[0][0]
#                                                                  activation_149[0][0]
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 30, 33)       21153       multiply_82[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 30, 33)       0           conv1d_81[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 30, 33)       0           conv1d_81[0][0]
# __________________________________________________________________________________________________
# multiply_83 (Multiply)          (None, 30, 33)       0           activation_150[0][0]
#                                                                  activation_151[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 30, 33)       0           multiply_83[0][0]
#                                                                  add_36[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 30, 128)      8576        add_37[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 30, 128)      0           conv1d_82[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 30, 128)      0           conv1d_82[0][0]
# __________________________________________________________________________________________________
# multiply_84 (Multiply)          (None, 30, 128)      0           activation_152[0][0]
#                                                                  activation_153[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 30, 33)       21153       multiply_84[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 30, 33)       0           conv1d_83[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 30, 33)       0           conv1d_83[0][0]
# __________________________________________________________________________________________________
# multiply_85 (Multiply)          (None, 30, 33)       0           activation_154[0][0]
#                                                                  activation_155[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 30, 33)       0           multiply_85[0][0]
#                                                                  add_37[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 30, 128)      8576        add_38[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 30, 128)      0           conv1d_84[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 30, 128)      0           conv1d_84[0][0]
# __________________________________________________________________________________________________
# multiply_86 (Multiply)          (None, 30, 128)      0           activation_156[0][0]
#                                                                  activation_157[0][0]
# __________________________________________________________________________________________________
# conv1d_85 (Conv1D)              (None, 30, 33)       21153       multiply_86[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 30, 33)       0           conv1d_85[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 30, 33)       0           conv1d_85[0][0]
# __________________________________________________________________________________________________
# multiply_87 (Multiply)          (None, 30, 33)       0           activation_158[0][0]
#                                                                  activation_159[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 30, 33)       0           multiply_87[0][0]
#                                                                  add_38[0][0]
# __________________________________________________________________________________________________
# conv1d_86 (Conv1D)              (None, 30, 512)      17408       add_39[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 30, 512)      0           conv1d_86[0][0]
# __________________________________________________________________________________________________
# conv1d_87 (Conv1D)              (None, 30, 256)      131328      dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 30, 256)      0           conv1d_87[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 256)          0           dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 12)           3084        global_average_pooling1d_3[0][0]
# ==================================================================================================
# Total params: 450,970
# Trainable params: 450,970
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
    # %%time
    histe = modele.fit(trXe, trYe, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaXe, vaYe), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Train on 19000 samples, validate on 2415 samples
# Epoch 1/1000
# 19000/19000 [==============================] - ETA: 0s - loss: 0.0434 - root_mean_squared_error: 0.0434 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0273 - mean_absolute_percentage_error: 1027.8157
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
# 19000/19000 [==============================] - 7s 367us/sample - loss: 0.0434 - root_mean_squared_error: 0.0434 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0273 - mean_absolute_percentage_error: 1027.8157 - val_loss: 0.1240 - val_root_mean_squared_error: 0.1245 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0677 - val_mean_absolute_percentage_error: 214.0567
# Epoch 2/1000
# 19000/19000 [==============================] - 6s 291us/sample - loss: 0.0423 - root_mean_squared_error: 0.0423 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0258 - mean_absolute_percentage_error: 562.2174 - val_loss: 0.1242 - val_root_mean_squared_error: 0.1247 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0673 - val_mean_absolute_percentage_error: 232.3654
# Epoch 3/1000
# 19000/19000 [==============================] - 5s 287us/sample - loss: 0.0420 - root_mean_squared_error: 0.0420 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0256 - mean_absolute_percentage_error: 571.8207 - val_loss: 0.1241 - val_root_mean_squared_error: 0.1242 - val_mean_squared_error: 0.0155 - val_mean_absolute_error: 0.0683 - val_mean_absolute_percentage_error: 232.0342
# Epoch 4/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0419 - root_mean_squared_error: 0.0419 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0256 - mean_absolute_percentage_error: 562.4152 - val_loss: 0.1231 - val_root_mean_squared_error: 0.1239 - val_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0692 - val_mean_absolute_percentage_error: 329.6707
# Epoch 5/1000
# 19000/19000 [==============================] - 5s 285us/sample - loss: 0.0415 - root_mean_squared_error: 0.0415 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0253 - mean_absolute_percentage_error: 597.1007 - val_loss: 0.1219 - val_root_mean_squared_error: 0.1204 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0672 - val_mean_absolute_percentage_error: 269.8264
# Epoch 6/1000
# 19000/19000 [==============================] - 5s 285us/sample - loss: 0.0410 - root_mean_squared_error: 0.0410 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0249 - mean_absolute_percentage_error: 593.3000 - val_loss: 0.1136 - val_root_mean_squared_error: 0.1136 - val_mean_squared_error: 0.0130 - val_mean_absolute_error: 0.0684 - val_mean_absolute_percentage_error: 577.6470
# Epoch 7/1000
# 19000/19000 [==============================] - 6s 296us/sample - loss: 0.0396 - root_mean_squared_error: 0.0396 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0244 - mean_absolute_percentage_error: 684.5483 - val_loss: 0.0974 - val_root_mean_squared_error: 0.0977 - val_mean_squared_error: 0.0095 - val_mean_absolute_error: 0.0601 - val_mean_absolute_percentage_error: 613.3108
# Epoch 8/1000
# 19000/19000 [==============================] - 6s 290us/sample - loss: 0.0379 - root_mean_squared_error: 0.0379 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0234 - mean_absolute_percentage_error: 607.7177 - val_loss: 0.0919 - val_root_mean_squared_error: 0.0915 - val_mean_squared_error: 0.0085 - val_mean_absolute_error: 0.0551 - val_mean_absolute_percentage_error: 559.5875
# Epoch 9/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0351 - root_mean_squared_error: 0.0351 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0220 - mean_absolute_percentage_error: 624.7737 - val_loss: 0.0750 - val_root_mean_squared_error: 0.0747 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0465 - val_mean_absolute_percentage_error: 727.0409
# Epoch 10/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0331 - root_mean_squared_error: 0.0331 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0209 - mean_absolute_percentage_error: 554.1868 - val_loss: 0.0710 - val_root_mean_squared_error: 0.0708 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0438 - val_mean_absolute_percentage_error: 705.7915
# Epoch 11/1000
# 19000/19000 [==============================] - 5s 284us/sample - loss: 0.0319 - root_mean_squared_error: 0.0319 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0202 - mean_absolute_percentage_error: 575.9470 - val_loss: 0.0725 - val_root_mean_squared_error: 0.0728 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0446 - val_mean_absolute_percentage_error: 732.5189
# Epoch 12/1000
# 19000/19000 [==============================] - 5s 286us/sample - loss: 0.0309 - root_mean_squared_error: 0.0309 - mean_squared_error: 0.0010 - mean_absolute_error: 0.0195 - mean_absolute_percentage_error: 555.9413 - val_loss: 0.0648 - val_root_mean_squared_error: 0.0647 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0392 - val_mean_absolute_percentage_error: 603.3803
# Epoch 13/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0302 - root_mean_squared_error: 0.0302 - mean_squared_error: 9.9311e-04 - mean_absolute_error: 0.0191 - mean_absolute_percentage_error: 540.1233 - val_loss: 0.0656 - val_root_mean_squared_error: 0.0655 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0394 - val_mean_absolute_percentage_error: 577.5648
# Epoch 14/1000
# 19000/19000 [==============================] - 6s 292us/sample - loss: 0.0292 - root_mean_squared_error: 0.0292 - mean_squared_error: 9.2847e-04 - mean_absolute_error: 0.0185 - mean_absolute_percentage_error: 528.4941 - val_loss: 0.0693 - val_root_mean_squared_error: 0.0693 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0403 - val_mean_absolute_percentage_error: 565.5027
# Epoch 15/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0285 - root_mean_squared_error: 0.0285 - mean_squared_error: 8.8415e-04 - mean_absolute_error: 0.0181 - mean_absolute_percentage_error: 490.0688 - val_loss: 0.0672 - val_root_mean_squared_error: 0.0676 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0396 - val_mean_absolute_percentage_error: 617.9307
# Epoch 16/1000
# 19000/19000 [==============================] - 6s 292us/sample - loss: 0.0279 - root_mean_squared_error: 0.0279 - mean_squared_error: 8.4301e-04 - mean_absolute_error: 0.0177 - mean_absolute_percentage_error: 476.1731 - val_loss: 0.0606 - val_root_mean_squared_error: 0.0606 - val_mean_squared_error: 0.0037 - val_mean_absolute_error: 0.0355 - val_mean_absolute_percentage_error: 494.1807
# Epoch 17/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0280 - root_mean_squared_error: 0.0280 - mean_squared_error: 8.5740e-04 - mean_absolute_error: 0.0178 - mean_absolute_percentage_error: 494.1956 - val_loss: 0.0639 - val_root_mean_squared_error: 0.0636 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0387 - val_mean_absolute_percentage_error: 657.3130
# Epoch 18/1000
# 19000/19000 [==============================] - 6s 291us/sample - loss: 0.0275 - root_mean_squared_error: 0.0275 - mean_squared_error: 8.0919e-04 - mean_absolute_error: 0.0175 - mean_absolute_percentage_error: 483.9948 - val_loss: 0.0628 - val_root_mean_squared_error: 0.0621 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0373 - val_mean_absolute_percentage_error: 605.8782
# Epoch 19/1000
# 19000/19000 [==============================] - 6s 290us/sample - loss: 0.0270 - root_mean_squared_error: 0.0270 - mean_squared_error: 7.7700e-04 - mean_absolute_error: 0.0171 - mean_absolute_percentage_error: 461.0755 - val_loss: 0.0619 - val_root_mean_squared_error: 0.0624 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0369 - val_mean_absolute_percentage_error: 577.1882
# Epoch 20/1000
# 19000/19000 [==============================] - 5s 287us/sample - loss: 0.0269 - root_mean_squared_error: 0.0269 - mean_squared_error: 7.7024e-04 - mean_absolute_error: 0.0170 - mean_absolute_percentage_error: 463.3108 - val_loss: 0.0584 - val_root_mean_squared_error: 0.0584 - val_mean_squared_error: 0.0034 - val_mean_absolute_error: 0.0354 - val_mean_absolute_percentage_error: 556.3550
# Epoch 21/1000
# 19000/19000 [==============================] - 5s 283us/sample - loss: 0.0269 - root_mean_squared_error: 0.0269 - mean_squared_error: 7.7020e-04 - mean_absolute_error: 0.0170 - mean_absolute_percentage_error: 484.8390 - val_loss: 0.0612 - val_root_mean_squared_error: 0.0610 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0362 - val_mean_absolute_percentage_error: 488.2327
# Epoch 22/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0266 - root_mean_squared_error: 0.0266 - mean_squared_error: 7.4997e-04 - mean_absolute_error: 0.0168 - mean_absolute_percentage_error: 466.4930 - val_loss: 0.0622 - val_root_mean_squared_error: 0.0621 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0364 - val_mean_absolute_percentage_error: 487.9804
# Epoch 23/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0264 - root_mean_squared_error: 0.0264 - mean_squared_error: 7.3896e-04 - mean_absolute_error: 0.0167 - mean_absolute_percentage_error: 450.1721 - val_loss: 0.0614 - val_root_mean_squared_error: 0.0613 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0357 - val_mean_absolute_percentage_error: 478.3925
# Epoch 24/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0262 - root_mean_squared_error: 0.0262 - mean_squared_error: 7.2694e-04 - mean_absolute_error: 0.0166 - mean_absolute_percentage_error: 484.5320 - val_loss: 0.0613 - val_root_mean_squared_error: 0.0610 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0350 - val_mean_absolute_percentage_error: 467.8991
# Epoch 25/1000
# 19000/19000 [==============================] - 6s 297us/sample - loss: 0.0262 - root_mean_squared_error: 0.0262 - mean_squared_error: 7.2434e-04 - mean_absolute_error: 0.0166 - mean_absolute_percentage_error: 485.0864 - val_loss: 0.0623 - val_root_mean_squared_error: 0.0626 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0367 - val_mean_absolute_percentage_error: 547.6900
# Epoch 26/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0261 - root_mean_squared_error: 0.0261 - mean_squared_error: 7.1665e-04 - mean_absolute_error: 0.0165 - mean_absolute_percentage_error: 467.7923 - val_loss: 0.0662 - val_root_mean_squared_error: 0.0659 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0395 - val_mean_absolute_percentage_error: 655.8462
# Epoch 27/1000
# 19000/19000 [==============================] - 5s 288us/sample - loss: 0.0261 - root_mean_squared_error: 0.0261 - mean_squared_error: 7.2418e-04 - mean_absolute_error: 0.0165 - mean_absolute_percentage_error: 475.4424 - val_loss: 0.0625 - val_root_mean_squared_error: 0.0619 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0375 - val_mean_absolute_percentage_error: 549.7846
# Epoch 28/1000
# 19000/19000 [==============================] - 5s 286us/sample - loss: 0.0261 - root_mean_squared_error: 0.0261 - mean_squared_error: 7.1875e-04 - mean_absolute_error: 0.0165 - mean_absolute_percentage_error: 468.9830 - val_loss: 0.0633 - val_root_mean_squared_error: 0.0640 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0363 - val_mean_absolute_percentage_error: 435.1146
# Epoch 29/1000
# 19000/19000 [==============================] - 5s 285us/sample - loss: 0.0258 - root_mean_squared_error: 0.0258 - mean_squared_error: 7.0307e-04 - mean_absolute_error: 0.0163 - mean_absolute_percentage_error: 458.6528 - val_loss: 0.0674 - val_root_mean_squared_error: 0.0668 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0382 - val_mean_absolute_percentage_error: 430.0113
# Epoch 30/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0255 - root_mean_squared_error: 0.0255 - mean_squared_error: 6.8287e-04 - mean_absolute_error: 0.0162 - mean_absolute_percentage_error: 427.5723 - val_loss: 0.0629 - val_root_mean_squared_error: 0.0624 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0364 - val_mean_absolute_percentage_error: 474.6547
# Epoch 31/1000
# 19000/19000 [==============================] - 5s 287us/sample - loss: 0.0256 - root_mean_squared_error: 0.0256 - mean_squared_error: 6.8802e-04 - mean_absolute_error: 0.0163 - mean_absolute_percentage_error: 450.1884 - val_loss: 0.0675 - val_root_mean_squared_error: 0.0669 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0396 - val_mean_absolute_percentage_error: 523.3889
# Epoch 32/1000
# 19000/19000 [==============================] - 5s 288us/sample - loss: 0.0255 - root_mean_squared_error: 0.0255 - mean_squared_error: 6.8028e-04 - mean_absolute_error: 0.0162 - mean_absolute_percentage_error: 467.2768 - val_loss: 0.0610 - val_root_mean_squared_error: 0.0614 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0363 - val_mean_absolute_percentage_error: 460.5532
# Epoch 33/1000
# 19000/19000 [==============================] - 5s 286us/sample - loss: 0.0253 - root_mean_squared_error: 0.0253 - mean_squared_error: 6.7662e-04 - mean_absolute_error: 0.0161 - mean_absolute_percentage_error: 442.1233 - val_loss: 0.0664 - val_root_mean_squared_error: 0.0655 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0379 - val_mean_absolute_percentage_error: 451.7690
# Epoch 34/1000
# 19000/19000 [==============================] - 5s 286us/sample - loss: 0.0251 - root_mean_squared_error: 0.0251 - mean_squared_error: 6.5889e-04 - mean_absolute_error: 0.0160 - mean_absolute_percentage_error: 473.6475 - val_loss: 0.0662 - val_root_mean_squared_error: 0.0669 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0376 - val_mean_absolute_percentage_error: 465.9484
# Epoch 35/1000
# 19000/19000 [==============================] - 5s 288us/sample - loss: 0.0249 - root_mean_squared_error: 0.0249 - mean_squared_error: 6.4330e-04 - mean_absolute_error: 0.0158 - mean_absolute_percentage_error: 453.3579 - val_loss: 0.0631 - val_root_mean_squared_error: 0.0635 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0367 - val_mean_absolute_percentage_error: 433.1371
# Epoch 36/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0248 - root_mean_squared_error: 0.0248 - mean_squared_error: 6.4470e-04 - mean_absolute_error: 0.0158 - mean_absolute_percentage_error: 444.7612 - val_loss: 0.0648 - val_root_mean_squared_error: 0.0636 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0365 - val_mean_absolute_percentage_error: 314.9287
# Epoch 37/1000
# 19000/19000 [==============================] - 6s 291us/sample - loss: 0.0248 - root_mean_squared_error: 0.0248 - mean_squared_error: 6.4344e-04 - mean_absolute_error: 0.0158 - mean_absolute_percentage_error: 465.0762 - val_loss: 0.0622 - val_root_mean_squared_error: 0.0619 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0358 - val_mean_absolute_percentage_error: 421.3668
# Epoch 38/1000
# 19000/19000 [==============================] - 6s 289us/sample - loss: 0.0250 - root_mean_squared_error: 0.0250 - mean_squared_error: 6.5705e-04 - mean_absolute_error: 0.0159 - mean_absolute_percentage_error: 453.1940 - val_loss: 0.0659 - val_root_mean_squared_error: 0.0654 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0389 - val_mean_absolute_percentage_error: 471.5507
# Epoch 39/1000
# 19000/19000 [==============================] - 5s 285us/sample - loss: 0.0249 - root_mean_squared_error: 0.0249 - mean_squared_error: 6.5430e-04 - mean_absolute_error: 0.0158 - mean_absolute_percentage_error: 460.3433 - val_loss: 0.0749 - val_root_mean_squared_error: 0.0748 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0412 - val_mean_absolute_percentage_error: 436.5382
# Epoch 40/1000
# 19000/19000 [==============================] - 6s 292us/sample - loss: 0.0246 - root_mean_squared_error: 0.0246 - mean_squared_error: 6.3745e-04 - mean_absolute_error: 0.0157 - mean_absolute_percentage_error: 454.0635 - val_loss: 0.0640 - val_root_mean_squared_error: 0.0638 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0365 - val_mean_absolute_percentage_error: 310.0185
# Epoch 41/1000
# 19000/19000 [==============================] - 6s 290us/sample - loss: 0.0244 - root_mean_squared_error: 0.0244 - mean_squared_error: 6.1846e-04 - mean_absolute_error: 0.0156 - mean_absolute_percentage_error: 447.0973 - val_loss: 0.0632 - val_root_mean_squared_error: 0.0634 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0368 - val_mean_absolute_percentage_error: 367.6537
# Epoch 42/1000
# 19000/19000 [==============================] - 5s 285us/sample - loss: 0.0242 - root_mean_squared_error: 0.0242 - mean_squared_error: 6.1072e-04 - mean_absolute_error: 0.0155 - mean_absolute_percentage_error: 461.3796 - val_loss: 0.0680 - val_root_mean_squared_error: 0.0672 - val_mean_squared_error: 0.0047 - val_mean_absolute_error: 0.0377 - val_mean_absolute_percentage_error: 335.4289
# Epoch 43/1000
# 19000/19000 [==============================] - 5s 288us/sample - loss: 0.0241 - root_mean_squared_error: 0.0241 - mean_squared_error: 6.0612e-04 - mean_absolute_error: 0.0154 - mean_absolute_percentage_error: 410.4158 - val_loss: 0.0650 - val_root_mean_squared_error: 0.0650 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0366 - val_mean_absolute_percentage_error: 344.2955
# Epoch 44/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0238 - root_mean_squared_error: 0.0238 - mean_squared_error: 5.8971e-04 - mean_absolute_error: 0.0153 - mean_absolute_percentage_error: 448.9096 - val_loss: 0.0638 - val_root_mean_squared_error: 0.0637 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0370 - val_mean_absolute_percentage_error: 337.0286
# Epoch 45/1000
# 19000/19000 [==============================] - 5s 284us/sample - loss: 0.0239 - root_mean_squared_error: 0.0239 - mean_squared_error: 5.9242e-04 - mean_absolute_error: 0.0153 - mean_absolute_percentage_error: 427.7744 - val_loss: 0.0662 - val_root_mean_squared_error: 0.0658 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0376 - val_mean_absolute_percentage_error: 325.6942
# Epoch 46/1000
# 19000/19000 [==============================] - 5s 288us/sample - loss: 0.0235 - root_mean_squared_error: 0.0235 - mean_squared_error: 5.7295e-04 - mean_absolute_error: 0.0151 - mean_absolute_percentage_error: 447.7348 - val_loss: 0.0656 - val_root_mean_squared_error: 0.0656 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0369 - val_mean_absolute_percentage_error: 358.4236
# Epoch 47/1000
# 19000/19000 [==============================] - 5s 287us/sample - loss: 0.0235 - root_mean_squared_error: 0.0235 - mean_squared_error: 5.7609e-04 - mean_absolute_error: 0.0151 - mean_absolute_percentage_error: 408.2031 - val_loss: 0.0687 - val_root_mean_squared_error: 0.0683 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0387 - val_mean_absolute_percentage_error: 341.9288
# Epoch 48/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0235 - root_mean_squared_error: 0.0235 - mean_squared_error: 5.7489e-04 - mean_absolute_error: 0.0151 - mean_absolute_percentage_error: 459.7112 - val_loss: 0.0651 - val_root_mean_squared_error: 0.0656 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0371 - val_mean_absolute_percentage_error: 363.5164
# Epoch 49/1000
# 19000/19000 [==============================] - 5s 287us/sample - loss: 0.0236 - root_mean_squared_error: 0.0236 - mean_squared_error: 5.7830e-04 - mean_absolute_error: 0.0152 - mean_absolute_percentage_error: 450.0734 - val_loss: 0.0699 - val_root_mean_squared_error: 0.0695 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0402 - val_mean_absolute_percentage_error: 336.0193
# Epoch 50/1000
# 19000/19000 [==============================] - 5s 283us/sample - loss: 0.0232 - root_mean_squared_error: 0.0232 - mean_squared_error: 5.5995e-04 - mean_absolute_error: 0.0150 - mean_absolute_percentage_error: 474.0410 - val_loss: 0.0692 - val_root_mean_squared_error: 0.0686 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0389 - val_mean_absolute_percentage_error: 323.0980
# Epoch 51/1000
# 19000/19000 [==============================] - 5s 283us/sample - loss: 0.0232 - root_mean_squared_error: 0.0232 - mean_squared_error: 5.5785e-04 - mean_absolute_error: 0.0150 - mean_absolute_percentage_error: 466.7900 - val_loss: 0.0660 - val_root_mean_squared_error: 0.0661 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0373 - val_mean_absolute_percentage_error: 357.1415
# Epoch 52/1000
# 19000/19000 [==============================] - 5s 286us/sample - loss: 0.0230 - root_mean_squared_error: 0.0230 - mean_squared_error: 5.4903e-04 - mean_absolute_error: 0.0149 - mean_absolute_percentage_error: 434.7813 - val_loss: 0.0641 - val_root_mean_squared_error: 0.0639 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0371 - val_mean_absolute_percentage_error: 403.3633
# Epoch 53/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0232 - root_mean_squared_error: 0.0232 - mean_squared_error: 5.6366e-04 - mean_absolute_error: 0.0151 - mean_absolute_percentage_error: 436.4387 - val_loss: 0.0743 - val_root_mean_squared_error: 0.0744 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0418 - val_mean_absolute_percentage_error: 382.9780
# Epoch 54/1000
# 19000/19000 [==============================] - 5s 284us/sample - loss: 0.0231 - root_mean_squared_error: 0.0231 - mean_squared_error: 5.5898e-04 - mean_absolute_error: 0.0150 - mean_absolute_percentage_error: 453.4711 - val_loss: 0.0706 - val_root_mean_squared_error: 0.0700 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0395 - val_mean_absolute_percentage_error: 314.5874
# Epoch 55/1000
# 19000/19000 [==============================] - 5s 288us/sample - loss: 0.0226 - root_mean_squared_error: 0.0226 - mean_squared_error: 5.2577e-04 - mean_absolute_error: 0.0146 - mean_absolute_percentage_error: 430.0024 - val_loss: 0.0667 - val_root_mean_squared_error: 0.0667 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0389 - val_mean_absolute_percentage_error: 397.0763
# Epoch 56/1000
# 19000/19000 [==============================] - 5s 283us/sample - loss: 0.0223 - root_mean_squared_error: 0.0223 - mean_squared_error: 5.1400e-04 - mean_absolute_error: 0.0146 - mean_absolute_percentage_error: 473.2578 - val_loss: 0.0664 - val_root_mean_squared_error: 0.0663 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0382 - val_mean_absolute_percentage_error: 364.9683
# Epoch 57/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0225 - root_mean_squared_error: 0.0225 - mean_squared_error: 5.2455e-04 - mean_absolute_error: 0.0146 - mean_absolute_percentage_error: 459.7236 - val_loss: 0.0753 - val_root_mean_squared_error: 0.0757 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0417 - val_mean_absolute_percentage_error: 294.7236
# Epoch 58/1000
# 19000/19000 [==============================] - 6s 292us/sample - loss: 0.0223 - root_mean_squared_error: 0.0223 - mean_squared_error: 5.1745e-04 - mean_absolute_error: 0.0145 - mean_absolute_percentage_error: 427.5320 - val_loss: 0.0727 - val_root_mean_squared_error: 0.0730 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0407 - val_mean_absolute_percentage_error: 303.9413
# Epoch 59/1000
# 19000/19000 [==============================] - 6s 296us/sample - loss: 0.0227 - root_mean_squared_error: 0.0227 - mean_squared_error: 5.3947e-04 - mean_absolute_error: 0.0147 - mean_absolute_percentage_error: 414.6484 - val_loss: 0.0663 - val_root_mean_squared_error: 0.0656 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0384 - val_mean_absolute_percentage_error: 402.1785
# Epoch 60/1000
# 19000/19000 [==============================] - 6s 292us/sample - loss: 0.0223 - root_mean_squared_error: 0.0223 - mean_squared_error: 5.1472e-04 - mean_absolute_error: 0.0145 - mean_absolute_percentage_error: 416.2056 - val_loss: 0.0718 - val_root_mean_squared_error: 0.0721 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0399 - val_mean_absolute_percentage_error: 367.0562
# Epoch 61/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0220 - root_mean_squared_error: 0.0220 - mean_squared_error: 4.9868e-04 - mean_absolute_error: 0.0144 - mean_absolute_percentage_error: 411.9826 - val_loss: 0.0702 - val_root_mean_squared_error: 0.0701 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0403 - val_mean_absolute_percentage_error: 323.2343
# Epoch 62/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0215 - root_mean_squared_error: 0.0215 - mean_squared_error: 4.7869e-04 - mean_absolute_error: 0.0141 - mean_absolute_percentage_error: 428.9605 - val_loss: 0.0694 - val_root_mean_squared_error: 0.0702 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0404 - val_mean_absolute_percentage_error: 320.6563
# Epoch 63/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0216 - root_mean_squared_error: 0.0216 - mean_squared_error: 4.8050e-04 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 421.7628 - val_loss: 0.0699 - val_root_mean_squared_error: 0.0707 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0395 - val_mean_absolute_percentage_error: 304.2921
# Epoch 64/1000
# 19000/19000 [==============================] - 6s 292us/sample - loss: 0.0216 - root_mean_squared_error: 0.0216 - mean_squared_error: 4.8087e-04 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 440.3972 - val_loss: 0.0720 - val_root_mean_squared_error: 0.0714 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0410 - val_mean_absolute_percentage_error: 317.4223
# Epoch 65/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0215 - root_mean_squared_error: 0.0215 - mean_squared_error: 4.7950e-04 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 435.1291 - val_loss: 0.0698 - val_root_mean_squared_error: 0.0698 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0393 - val_mean_absolute_percentage_error: 290.6014
# Epoch 66/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0216 - root_mean_squared_error: 0.0216 - mean_squared_error: 4.8065e-04 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 427.1308 - val_loss: 0.0677 - val_root_mean_squared_error: 0.0682 - val_mean_squared_error: 0.0047 - val_mean_absolute_error: 0.0391 - val_mean_absolute_percentage_error: 379.7897
# Epoch 67/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0216 - root_mean_squared_error: 0.0216 - mean_squared_error: 4.8224e-04 - mean_absolute_error: 0.0142 - mean_absolute_percentage_error: 430.6751 - val_loss: 0.0727 - val_root_mean_squared_error: 0.0721 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0406 - val_mean_absolute_percentage_error: 304.6818
# Epoch 68/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0213 - root_mean_squared_error: 0.0213 - mean_squared_error: 4.6611e-04 - mean_absolute_error: 0.0141 - mean_absolute_percentage_error: 463.5601 - val_loss: 0.0724 - val_root_mean_squared_error: 0.0721 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0408 - val_mean_absolute_percentage_error: 305.1451
# Epoch 69/1000
# 19000/19000 [==============================] - 6s 290us/sample - loss: 0.0210 - root_mean_squared_error: 0.0210 - mean_squared_error: 4.5710e-04 - mean_absolute_error: 0.0139 - mean_absolute_percentage_error: 411.2094 - val_loss: 0.0729 - val_root_mean_squared_error: 0.0725 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0407 - val_mean_absolute_percentage_error: 288.8036
# Epoch 70/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0209 - root_mean_squared_error: 0.0209 - mean_squared_error: 4.4969e-04 - mean_absolute_error: 0.0138 - mean_absolute_percentage_error: 428.7880 - val_loss: 0.0703 - val_root_mean_squared_error: 0.0695 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0400 - val_mean_absolute_percentage_error: 303.7370
# Epoch 71/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0209 - root_mean_squared_error: 0.0209 - mean_squared_error: 4.5309e-04 - mean_absolute_error: 0.0139 - mean_absolute_percentage_error: 411.3504 - val_loss: 0.0707 - val_root_mean_squared_error: 0.0710 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0416 - val_mean_absolute_percentage_error: 384.6634
# Epoch 72/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0210 - root_mean_squared_error: 0.0210 - mean_squared_error: 4.5988e-04 - mean_absolute_error: 0.0139 - mean_absolute_percentage_error: 433.3317 - val_loss: 0.0768 - val_root_mean_squared_error: 0.0757 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0416 - val_mean_absolute_percentage_error: 355.3478
# Epoch 73/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0209 - root_mean_squared_error: 0.0209 - mean_squared_error: 4.5154e-04 - mean_absolute_error: 0.0138 - mean_absolute_percentage_error: 404.9957 - val_loss: 0.0731 - val_root_mean_squared_error: 0.0727 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0418 - val_mean_absolute_percentage_error: 305.6088
# Epoch 74/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0206 - root_mean_squared_error: 0.0206 - mean_squared_error: 4.4081e-04 - mean_absolute_error: 0.0137 - mean_absolute_percentage_error: 431.0777 - val_loss: 0.0757 - val_root_mean_squared_error: 0.0749 - val_mean_squared_error: 0.0058 - val_mean_absolute_error: 0.0440 - val_mean_absolute_percentage_error: 356.3550
# Epoch 75/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0206 - root_mean_squared_error: 0.0206 - mean_squared_error: 4.3808e-04 - mean_absolute_error: 0.0137 - mean_absolute_percentage_error: 430.6435 - val_loss: 0.0744 - val_root_mean_squared_error: 0.0746 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0415 - val_mean_absolute_percentage_error: 325.5740
# Epoch 76/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0204 - root_mean_squared_error: 0.0204 - mean_squared_error: 4.2697e-04 - mean_absolute_error: 0.0135 - mean_absolute_percentage_error: 420.8236 - val_loss: 0.0695 - val_root_mean_squared_error: 0.0695 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0390 - val_mean_absolute_percentage_error: 319.4507
# Epoch 77/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0204 - root_mean_squared_error: 0.0204 - mean_squared_error: 4.2999e-04 - mean_absolute_error: 0.0136 - mean_absolute_percentage_error: 434.9881 - val_loss: 0.0703 - val_root_mean_squared_error: 0.0699 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0410 - val_mean_absolute_percentage_error: 405.4882
# Epoch 78/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0203 - root_mean_squared_error: 0.0203 - mean_squared_error: 4.2728e-04 - mean_absolute_error: 0.0135 - mean_absolute_percentage_error: 416.0508 - val_loss: 0.0729 - val_root_mean_squared_error: 0.0729 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0413 - val_mean_absolute_percentage_error: 295.7813
# Epoch 79/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0203 - root_mean_squared_error: 0.0203 - mean_squared_error: 4.2773e-04 - mean_absolute_error: 0.0135 - mean_absolute_percentage_error: 458.1295 - val_loss: 0.0737 - val_root_mean_squared_error: 0.0729 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0411 - val_mean_absolute_percentage_error: 289.5321
# Epoch 80/1000
# 19000/19000 [==============================] - 6s 292us/sample - loss: 0.0201 - root_mean_squared_error: 0.0201 - mean_squared_error: 4.1693e-04 - mean_absolute_error: 0.0134 - mean_absolute_percentage_error: 427.0259 - val_loss: 0.0719 - val_root_mean_squared_error: 0.0729 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0402 - val_mean_absolute_percentage_error: 288.2376
# Epoch 81/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0200 - root_mean_squared_error: 0.0200 - mean_squared_error: 4.1233e-04 - mean_absolute_error: 0.0134 - mean_absolute_percentage_error: 410.2563 - val_loss: 0.0722 - val_root_mean_squared_error: 0.0720 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0409 - val_mean_absolute_percentage_error: 319.6104
# Epoch 82/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0200 - root_mean_squared_error: 0.0200 - mean_squared_error: 4.1304e-04 - mean_absolute_error: 0.0134 - mean_absolute_percentage_error: 406.5808 - val_loss: 0.0728 - val_root_mean_squared_error: 0.0742 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0427 - val_mean_absolute_percentage_error: 382.0085
# Epoch 83/1000
# 19000/19000 [==============================] - 6s 297us/sample - loss: 0.0201 - root_mean_squared_error: 0.0201 - mean_squared_error: 4.1794e-04 - mean_absolute_error: 0.0134 - mean_absolute_percentage_error: 421.3910 - val_loss: 0.0729 - val_root_mean_squared_error: 0.0736 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0399 - val_mean_absolute_percentage_error: 336.3428
# Epoch 84/1000
# 19000/19000 [==============================] - 6s 297us/sample - loss: 0.0198 - root_mean_squared_error: 0.0198 - mean_squared_error: 4.0229e-04 - mean_absolute_error: 0.0132 - mean_absolute_percentage_error: 424.0461 - val_loss: 0.0710 - val_root_mean_squared_error: 0.0702 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0395 - val_mean_absolute_percentage_error: 279.5065
# Epoch 85/1000
# 19000/19000 [==============================] - 6s 298us/sample - loss: 0.0197 - root_mean_squared_error: 0.0197 - mean_squared_error: 3.9950e-04 - mean_absolute_error: 0.0132 - mean_absolute_percentage_error: 404.7880 - val_loss: 0.0711 - val_root_mean_squared_error: 0.0706 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0406 - val_mean_absolute_percentage_error: 316.1583
# Epoch 86/1000
# 19000/19000 [==============================] - 6s 296us/sample - loss: 0.0197 - root_mean_squared_error: 0.0197 - mean_squared_error: 4.0237e-04 - mean_absolute_error: 0.0132 - mean_absolute_percentage_error: 424.0607 - val_loss: 0.0792 - val_root_mean_squared_error: 0.0810 - val_mean_squared_error: 0.0063 - val_mean_absolute_error: 0.0448 - val_mean_absolute_percentage_error: 286.5493
# Epoch 87/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0199 - root_mean_squared_error: 0.0199 - mean_squared_error: 4.1027e-04 - mean_absolute_error: 0.0133 - mean_absolute_percentage_error: 443.5649 - val_loss: 0.0705 - val_root_mean_squared_error: 0.0706 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0394 - val_mean_absolute_percentage_error: 298.5804
# Epoch 88/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0198 - root_mean_squared_error: 0.0198 - mean_squared_error: 4.0836e-04 - mean_absolute_error: 0.0133 - mean_absolute_percentage_error: 396.1745 - val_loss: 0.0685 - val_root_mean_squared_error: 0.0690 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0390 - val_mean_absolute_percentage_error: 356.5563
# Epoch 89/1000
# 19000/19000 [==============================] - 6s 296us/sample - loss: 0.0198 - root_mean_squared_error: 0.0198 - mean_squared_error: 4.0977e-04 - mean_absolute_error: 0.0133 - mean_absolute_percentage_error: 414.0903 - val_loss: 0.0784 - val_root_mean_squared_error: 0.0771 - val_mean_squared_error: 0.0062 - val_mean_absolute_error: 0.0423 - val_mean_absolute_percentage_error: 293.5880
# Epoch 90/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0195 - root_mean_squared_error: 0.0195 - mean_squared_error: 3.9206e-04 - mean_absolute_error: 0.0131 - mean_absolute_percentage_error: 429.6451 - val_loss: 0.0730 - val_root_mean_squared_error: 0.0728 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0410 - val_mean_absolute_percentage_error: 299.1125
# Epoch 91/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0192 - root_mean_squared_error: 0.0192 - mean_squared_error: 3.8114e-04 - mean_absolute_error: 0.0130 - mean_absolute_percentage_error: 413.3499 - val_loss: 0.0751 - val_root_mean_squared_error: 0.0748 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0422 - val_mean_absolute_percentage_error: 300.6513
# Epoch 92/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0192 - root_mean_squared_error: 0.0192 - mean_squared_error: 3.7741e-04 - mean_absolute_error: 0.0129 - mean_absolute_percentage_error: 451.9078 - val_loss: 0.0713 - val_root_mean_squared_error: 0.0708 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0397 - val_mean_absolute_percentage_error: 314.4072
# Epoch 93/1000
# 19000/19000 [==============================] - 6s 292us/sample - loss: 0.0191 - root_mean_squared_error: 0.0191 - mean_squared_error: 3.7642e-04 - mean_absolute_error: 0.0129 - mean_absolute_percentage_error: 418.9097 - val_loss: 0.0707 - val_root_mean_squared_error: 0.0706 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0402 - val_mean_absolute_percentage_error: 318.4757
# Epoch 94/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0191 - root_mean_squared_error: 0.0191 - mean_squared_error: 3.7651e-04 - mean_absolute_error: 0.0129 - mean_absolute_percentage_error: 428.1489 - val_loss: 0.0738 - val_root_mean_squared_error: 0.0735 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0415 - val_mean_absolute_percentage_error: 299.1581
# Epoch 95/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0190 - root_mean_squared_error: 0.0190 - mean_squared_error: 3.7288e-04 - mean_absolute_error: 0.0128 - mean_absolute_percentage_error: 426.8687 - val_loss: 0.0752 - val_root_mean_squared_error: 0.0749 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0422 - val_mean_absolute_percentage_error: 319.7004
# Epoch 96/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0190 - root_mean_squared_error: 0.0190 - mean_squared_error: 3.7031e-04 - mean_absolute_error: 0.0128 - mean_absolute_percentage_error: 392.8972 - val_loss: 0.0761 - val_root_mean_squared_error: 0.0758 - val_mean_squared_error: 0.0058 - val_mean_absolute_error: 0.0433 - val_mean_absolute_percentage_error: 277.3750
# Epoch 97/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0192 - root_mean_squared_error: 0.0192 - mean_squared_error: 3.8413e-04 - mean_absolute_error: 0.0129 - mean_absolute_percentage_error: 422.3867 - val_loss: 0.0707 - val_root_mean_squared_error: 0.0704 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0392 - val_mean_absolute_percentage_error: 322.8182
# Epoch 98/1000
# 19000/19000 [==============================] - 6s 296us/sample - loss: 0.0191 - root_mean_squared_error: 0.0191 - mean_squared_error: 3.7595e-04 - mean_absolute_error: 0.0129 - mean_absolute_percentage_error: 416.2203 - val_loss: 0.0745 - val_root_mean_squared_error: 0.0752 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0418 - val_mean_absolute_percentage_error: 320.7731
# Epoch 99/1000
# 19000/19000 [==============================] - 6s 297us/sample - loss: 0.0190 - root_mean_squared_error: 0.0190 - mean_squared_error: 3.7172e-04 - mean_absolute_error: 0.0128 - mean_absolute_percentage_error: 433.4950 - val_loss: 0.0761 - val_root_mean_squared_error: 0.0759 - val_mean_squared_error: 0.0058 - val_mean_absolute_error: 0.0426 - val_mean_absolute_percentage_error: 298.3586
# Epoch 100/1000
# 19000/19000 [==============================] - 6s 293us/sample - loss: 0.0186 - root_mean_squared_error: 0.0186 - mean_squared_error: 3.5719e-04 - mean_absolute_error: 0.0126 - mean_absolute_percentage_error: 428.2217 - val_loss: 0.0738 - val_root_mean_squared_error: 0.0746 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0412 - val_mean_absolute_percentage_error: 282.6816
# Epoch 101/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0188 - root_mean_squared_error: 0.0188 - mean_squared_error: 3.6253e-04 - mean_absolute_error: 0.0127 - mean_absolute_percentage_error: 396.4878 - val_loss: 0.0720 - val_root_mean_squared_error: 0.0735 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0410 - val_mean_absolute_percentage_error: 322.7038
# Epoch 102/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0186 - root_mean_squared_error: 0.0186 - mean_squared_error: 3.5595e-04 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 433.4506 - val_loss: 0.0725 - val_root_mean_squared_error: 0.0720 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0407 - val_mean_absolute_percentage_error: 337.6484
# Epoch 103/1000
# 19000/19000 [==============================] - 6s 295us/sample - loss: 0.0185 - root_mean_squared_error: 0.0185 - mean_squared_error: 3.5306e-04 - mean_absolute_error: 0.0126 - mean_absolute_percentage_error: 428.1299 - val_loss: 0.0766 - val_root_mean_squared_error: 0.0761 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0433 - val_mean_absolute_percentage_error: 293.6331
# Epoch 104/1000
# 19000/19000 [==============================] - 6s 294us/sample - loss: 0.0185 - root_mean_squared_error: 0.0185 - mean_squared_error: 3.5399e-04 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 408.9861 - val_loss: 0.0749 - val_root_mean_squared_error: 0.0746 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0418 - val_mean_absolute_percentage_error: 288.8832
# Epoch 105/1000
# 19000/19000 [==============================] - 6s 296us/sample - loss: 0.0185 - root_mean_squared_error: 0.0185 - mean_squared_error: 3.5200e-04 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 405.2776 - val_loss: 0.0714 - val_root_mean_squared_error: 0.0714 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0399 - val_mean_absolute_percentage_error: 297.5056
# Epoch 106/1000
# 19000/19000 [==============================] - 6s 290us/sample - loss: 0.0185 - root_mean_squared_error: 0.0185 - mean_squared_error: 3.5135e-04 - mean_absolute_error: 0.0126 - mean_absolute_percentage_error: 410.7196 - val_loss: 0.0708 - val_root_mean_squared_error: 0.0705 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0397 - val_mean_absolute_percentage_error: 280.6434
# Epoch 107/1000
# 19000/19000 [==============================] - 5s 285us/sample - loss: 0.0184 - root_mean_squared_error: 0.0184 - mean_squared_error: 3.4762e-04 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 398.9370 - val_loss: 0.0779 - val_root_mean_squared_error: 0.0773 - val_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0439 - val_mean_absolute_percentage_error: 284.4398
# Epoch 108/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0184 - root_mean_squared_error: 0.0184 - mean_squared_error: 3.5057e-04 - mean_absolute_error: 0.0125 - mean_absolute_percentage_error: 436.2547 - val_loss: 0.0772 - val_root_mean_squared_error: 0.0784 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0431 - val_mean_absolute_percentage_error: 274.3894
# Epoch 109/1000
# 19000/19000 [==============================] - 5s 286us/sample - loss: 0.0183 - root_mean_squared_error: 0.0183 - mean_squared_error: 3.4385e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 409.0427 - val_loss: 0.0709 - val_root_mean_squared_error: 0.0715 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0393 - val_mean_absolute_percentage_error: 280.4020
# Epoch 110/1000
# 19000/19000 [==============================] - 5s 287us/sample - loss: 0.0182 - root_mean_squared_error: 0.0182 - mean_squared_error: 3.4078e-04 - mean_absolute_error: 0.0124 - mean_absolute_percentage_error: 402.8365 - val_loss: 0.0726 - val_root_mean_squared_error: 0.0724 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0405 - val_mean_absolute_percentage_error: 301.0871
# Epoch 111/1000
# 19000/19000 [==============================] - 5s 287us/sample - loss: 0.0181 - root_mean_squared_error: 0.0181 - mean_squared_error: 3.3582e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 434.2815 - val_loss: 0.0753 - val_root_mean_squared_error: 0.0749 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0421 - val_mean_absolute_percentage_error: 270.5307
# Epoch 112/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0180 - root_mean_squared_error: 0.0180 - mean_squared_error: 3.3384e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 403.8942 - val_loss: 0.0774 - val_root_mean_squared_error: 0.0780 - val_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0432 - val_mean_absolute_percentage_error: 257.5536
# Epoch 113/1000
# 19000/19000 [==============================] - 5s 283us/sample - loss: 0.0180 - root_mean_squared_error: 0.0180 - mean_squared_error: 3.3144e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 402.2309 - val_loss: 0.0725 - val_root_mean_squared_error: 0.0722 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0405 - val_mean_absolute_percentage_error: 292.3788
# Epoch 114/1000
# 19000/19000 [==============================] - 5s 284us/sample - loss: 0.0181 - root_mean_squared_error: 0.0181 - mean_squared_error: 3.3783e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 403.5498 - val_loss: 0.0706 - val_root_mean_squared_error: 0.0701 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0398 - val_mean_absolute_percentage_error: 304.8695
# Epoch 115/1000
# 19000/19000 [==============================] - 5s 284us/sample - loss: 0.0180 - root_mean_squared_error: 0.0180 - mean_squared_error: 3.3402e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 386.6193 - val_loss: 0.0771 - val_root_mean_squared_error: 0.0758 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0423 - val_mean_absolute_percentage_error: 272.3309
# Epoch 116/1000
# 19000/19000 [==============================] - 5s 283us/sample - loss: 0.0178 - root_mean_squared_error: 0.0178 - mean_squared_error: 3.2553e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 398.8179 - val_loss: 0.0780 - val_root_mean_squared_error: 0.0778 - val_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0431 - val_mean_absolute_percentage_error: 274.8877
# Epoch 117/1000
# 19000/19000 [==============================] - 5s 289us/sample - loss: 0.0179 - root_mean_squared_error: 0.0179 - mean_squared_error: 3.3370e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 386.1973 - val_loss: 0.0748 - val_root_mean_squared_error: 0.0744 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0420 - val_mean_absolute_percentage_error: 256.8999
# Epoch 118/1000
# 19000/19000 [==============================] - 5s 285us/sample - loss: 0.0182 - root_mean_squared_error: 0.0182 - mean_squared_error: 3.4159e-04 - mean_absolute_error: 0.0123 - mean_absolute_percentage_error: 393.7922 - val_loss: 0.0718 - val_root_mean_squared_error: 0.0715 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0414 - val_mean_absolute_percentage_error: 311.2365
# Epoch 119/1000
# 19000/19000 [==============================] - 5s 287us/sample - loss: 0.0179 - root_mean_squared_error: 0.0179 - mean_squared_error: 3.3094e-04 - mean_absolute_error: 0.0122 - mean_absolute_percentage_error: 428.9366 - val_loss: 0.0746 - val_root_mean_squared_error: 0.0744 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0412 - val_mean_absolute_percentage_error: 301.7130
# Epoch 120/1000
# 19000/19000 [==============================] - 5s 284us/sample - loss: 0.0178 - root_mean_squared_error: 0.0178 - mean_squared_error: 3.3014e-04 - mean_absolute_error: 0.0121 - mean_absolute_percentage_error: 389.8877 - val_loss: 0.0780 - val_root_mean_squared_error: 0.0779 - val_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0421 - val_mean_absolute_percentage_error: 247.4392
# Wall time: 11min 10s

# %%
dataset = np.hstack([pv_dat, weather_dat])
index = ['Measured PV', 'Temperature C', 'Rainfall', 'Wind speed', 'Wind direction', 'Humidity', 'Air pressure', 'Dew point C', 'Sunshine', 'Solar radiation', 'Snowfall', 'Cloud cover', 'Surface temp C']

df = pd.DataFrame(dataset, columns=index)
df.head()
df = df.fillna(0)
min_max_scaler = preprocessing.MinMaxScaler()
norm_df = pd.DataFrame(min_max_scaler.fit_transform(df), 
                             columns=df.columns, 
                             index=df.index)
norm_df2 = norm_df.iloc[21447:, [0, 1, 4, 5, 6, 8, 9, 11, 12]]
eteX, eteY = create_dataset(np.array(norm_df2), timesteps, output_timesteps)

print(eteX.shape)
print(eteY.shape)
print(tePredict.reshape(-1,12).shape)

npnorm2 =np.array(norm_df2)
npnorm2 = npnorm2[30:-13,:]
print(npnorm2.shape)
# Out:
# (9169, 30, 9)
# (9169, 1, 9)
# (9158, 12)
# (9158, 9)

# %%
pr_df = pd.DataFrame(tePredict.reshape(-1,12), columns=Prindex)
pr_df.head()
# Out:
#    Prediction1  Prediction2  Prediction3  Prediction4  Prediction5  \
# 0    -0.007720    -0.006757    -0.006949    -0.008514    -0.011227
# 1    -0.013791    -0.009037    -0.008682    -0.009985    -0.012580
# 2    -0.014430    -0.011359    -0.010078    -0.013157    -0.020080
# 3    -0.013391    -0.011080    -0.010040    -0.012543    -0.020417
# 4    -0.002458    -0.003912    -0.005194    -0.009110    -0.017565
#
#    Prediction6  Prediction7  Prediction8  Prediction9  Prediction10  \
# 0    -0.012366    -0.011200    -0.008740    -0.005066     -0.003351
# 1    -0.013338    -0.013471    -0.013749     0.000509      0.054798
# 2    -0.024239    -0.019777     0.014955     0.112060      0.267585
# 3    -0.024057    -0.019324     0.021670     0.129658      0.285694
# 4    -0.018422    -0.010709     0.037760     0.164700      0.340803
#
#    Prediction11  Prediction12
# 0      0.007621      0.052978
# 1      0.162886      0.298371
# 2      0.437533      0.557074
# 3      0.443205      0.556512
# 4      0.486994      0.560777

# %%
teY = testY.reshape(-1,12)
e_te = testPredict-teY
er_df = pd.DataFrame(e_te, columns=Erindex)
er_df.head()
# Out:
#      Error1    Error2    Error3    Error4    Error5    Error6    Error7  \
# 0 -0.007720 -0.006757 -0.006949 -0.008514 -0.011227 -0.012366 -0.011200
# 1 -0.013791 -0.009037 -0.008682 -0.009985 -0.012580 -0.013338 -0.013471
# 2 -0.014430 -0.011359 -0.010078 -0.013157 -0.020080 -0.024239 -0.019777
# 3 -0.013391 -0.011080 -0.010040 -0.012543 -0.020417 -0.024057 -0.072812
# 4 -0.002458 -0.003912 -0.005194 -0.009110 -0.017565 -0.071910 -0.216910
#
#      Error8    Error9   Error10   Error11   Error12
# 0 -0.008740 -0.005066 -0.056839 -0.198580 -0.300511
# 1 -0.013749 -0.052979 -0.151403 -0.190602 -0.284574
# 2 -0.038533 -0.094141 -0.085904 -0.145413 -0.058430
# 3 -0.184531 -0.223830 -0.297252 -0.172298  0.140233
# 4 -0.315728 -0.418246 -0.274701  0.070715  0.015041

# %%
prnorm = np.array(pr_df)
ernorm =np.array(er_df)
print(ernorm.shape)
# Out:
# (9158, 12)

# %%
etedat = np.concatenate((npnorm2, prnorm, ernorm), axis=1)
print(etedat.shape)
# Out:
# (9158, 33)

# %%
eteX, eteY = create_dataset(etedat, timesteps, output_timesteps)
eteY = eteY[:,:,-12:].reshape(-1,12)
print(eteX.shape)
print(eteY.shape)
# Out:
# (9126, 30, 33)
# (9126, 12)

# %%
etePredict = modele.predict(eteX, batch_size=batch_size)
print(etePredict.shape)
print(etePredict)
# Out:
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
# (9126, 12)
# [[-0.02893954 -0.02136326 -0.01281369 ...  0.04458101 -0.01474411
#   -0.00357246]
#  [-0.03535176 -0.01455062 -0.02473891 ...  0.00690825 -0.00121909
#    0.0096518 ]
#  [-0.01554582 -0.01282716 -0.03342522 ...  0.04380946  0.03999922
#    0.01537228]
#  ...
#  [ 0.00039806 -0.0055665   0.00801497 ... -0.02191847 -0.0705566
#   -0.05811049]
#  [-0.02595669 -0.05217758 -0.05683371 ... -0.05382672 -0.0579668
#   -0.03511968]
#  [-0.0679294  -0.12153579 -0.09068701 ... -0.02748858 -0.04096749
#   -0.01908051]]

# %%
testPredict = tePredict.reshape(-1,12)
addtestPredict = -etePredict + testPredict[30:-2,:]
print(addtestPredict.shape)
# Out:
# (9126, 12)

# %%
print('Error Test Score > RMSE == ', np.sqrt(np.mean(np.square(teY[30:-2,:]-testPredict[30:-2,:]))), ' MAE == ', mean_absolute_error(teY[30:-2,:], testPredict[30:-2,:]), 'MAPE == ', mean_absolute_percentage_error(teY[30:-2,:], testPredict[30:-2,:]))
print('Error Test Score > RMSE == ', np.sqrt(np.mean(np.square(teY[30:-2,:]-addtestPredict))), ' MAE == ', mean_absolute_error(teY[30:-2,:], addtestPredict), 'MAPE == ', mean_absolute_percentage_error(teY[30:-2,:], addtestPredict))
# Out:
# Error Test Score > RMSE ==  0.11873171290951115  MAE ==  0.06421819626162564 MAPE ==  inf
# Error Test Score > RMSE ==  0.0753210975410989  MAE ==  0.04197179682979368 MAPE ==  inf
# divide by zero encountered in true_divide
# divide by zero encountered in true_divide

# %%
np.savetxt('FSEFF_EL_FinaltestPredict.txt', addtestPredict)

# %%
layer_outputs = [layer.output for layer in modele.layers if layer.name=='attention_vece']
activation_model = tf.keras.models.Model(inputs=modele.input, outputs=layer_outputs)
attention_vectors = []
output_data = activation_model.predict(eteX, batch_size=batch_size)
output_data = np.array(output_data)
print(output_data.shape)
at_vec = np.mean(output_data, axis=0)
print(at_vec, at_vec.shape)
np.savetxt('Attention_FSEFF_EL.txt', at_vec)
at_vec = abs(at_vec)
# Out:
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#    5.02714440e-02  1.33580923e-01  1.27159998e-01  1.24739207e-01
#    1.25514805e-01  1.28011823e-01  1.29099086e-01  1.30014867e-01
#    1.30400687e-01  1.26634225e-01  1.21918224e-01  1.21215850e-01
#    1.25329435e-01  3.16645861e-01  3.08002561e-01  3.05412441e-01
#    3.07040542e-01  3.11005563e-01  3.12784106e-01  3.14225256e-01
#    3.14583749e-01  3.08643699e-01  3.01254064e-01  2.99904227e-01
#    3.06014687e-01]
#  [ 9.42644253e-02 -9.28707868e-02 -8.09341520e-02 -2.52389479e-02
#    1.46099692e-03  1.11903027e-02  1.08804770e-01 -2.30355188e-02
#   -7.31505528e-02  1.31963432e-01  1.05962627e-01  9.55838189e-02
#    9.89937708e-02  1.09879978e-01  1.14569299e-01  1.18519656e-01
#    1.20231926e-01  1.04295261e-01  8.46906677e-02  8.26400667e-02
#    1.00840606e-01  7.12599158e-01  6.92104161e-01  6.80903435e-01
#    6.79729283e-01  6.83919072e-01  6.84086502e-01  6.83245659e-01
#    6.81869209e-01  6.71282709e-01  6.56892240e-01  6.52156472e-01
#    6.61734998e-01]] (30, 33)

# %%
import shap
shap.initjs()
background = trXe[np.random.choice(trXe.shape[0], 300, replace=False)]
print(background.shape)
explainer = shap.DeepExplainer(modele, background)
test_sample = trXe[-100:]
shap_values = explainer.shap_values(background)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# (300, 30, 33)

# %%
index2 = np.concatenate([index, Prindex, Erindex])

# %%
shap.summary_plot(shap_values[0][0], background[0], feature_names=index2)
#shap.force_plot(explainer.expected_value[0], shap_values[0], feature_names=index)

# %%
shap_np = np.array(shap_values[0])
shap_np = shap_np.reshape(-1,num_features)
print("=========================================================================")
print(shap_np)
np.savetxt('SHAP_VALUES_FSEFF_EL.txt', shap_np)
# Out:
# =========================================================================
# [[-2.96598252e-05  2.62115826e-04  5.86321122e-05 ...  8.60085544e-06
#    2.62683214e-05  1.30364545e-05]
#  [ 1.15300899e-04  6.85982730e-05  3.37032701e-05 ... -9.53116146e-06
#   -9.02740348e-07  2.20842157e-05]
#  [ 4.61570865e-05 -1.24187936e-04 -6.22912190e-05 ... -1.58204312e-05
#   -1.23638763e-05 -2.54873732e-07]
#  ...
#  [-1.78037078e-04 -7.54175323e-05 -1.19701233e-05 ...  1.69111734e-03
#   -1.55961947e-03 -8.01714359e-05]
#  [ 1.52703563e-04 -4.80134808e-04 -2.66011549e-04 ... -2.12266981e-03
#   -2.69197806e-04 -6.81521050e-05]
#  [-2.04823014e-05 -6.14498221e-05  8.35338167e-06 ...  2.94353144e-04
#   -2.61574287e-04 -2.11329574e-04]]

# %%
shap.initjs()
background = trX[np.random.choice(trX.shape[0], 300, replace=False)]
print(background.shape)
explainer = shap.DeepExplainer(model, background)
test_sample = trX[-100:]
shap_values = explainer.shap_values(background)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# (300, 30, 9)

# %%
shap.summary_plot(shap_values[0][0], background[0], feature_names=index)
#shap.force_plot(explainer.expected_value[0], shap_values[0], feature_names=index)

# %%
shap_np = np.array(shap_values[0])
shap_np = shap_np.reshape(-1,9)
print("=========================================================================")
print(shap_np)
np.savetxt('SHAP_VALUES_FSEFF.txt', shap_np)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-b0f9b9f04e24> in <module>
#       1 shap_np = np.array(shap_values[0])
# ----> 2 shap_np = shap_np.reshape(-1,num_features)
#       3 print("=========================================================================")
#       4 print(shap_np)
#       5 np.savetxt('SHAP_VALUES_FSEFF.txt', shap_np)
#
# ValueError: cannot reshape array of size 81000 into shape (33)

# %%
plt.figure(figsize=(16,8)) 
plt.plot(tePredict[30:330,:])
plt.plot(addtestPredict[0:300,:])
plt.plot(testY[30:330,:])
plt.ylabel('Value')
plt.xlabel('time(h)')
plt.legend(['tePredict', 'testY'], loc='upper left')
plt.show()
